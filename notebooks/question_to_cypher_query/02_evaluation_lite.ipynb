# %% [markdown]
# # Question-to-Cypher (Q2C) — E2E Evaluation
#
# Notebook untuk mengevaluasi pipeline E2E: **Question → Cypher → Neo4j → Answer**.
#
# **Alur:**
# 1. Load test data dari Google Sheets / CSV (berisi `TEST_ID`, `QUESTION`)
# 2. Kirim setiap pertanyaan ke backend `/api/qa`
# 3. Capture: `GENERATED_CYPHER`, `CYPHER_QUERY_RESULT`, `ANSWER`, `STATUS`
# 4. Hitung pass rate per kategori
# 5. Tulis hasil ke Google Sheets
#
# **Perbedaan dari `04_evaluation.ipynb` (KG Extraction):**
# - KG Extraction: query Cypher sudah ada di test data, hanya execute + compare
# - Q2C E2E: **question saja** → backend generate Cypher → execute → jawab

# %%
# === Setup ===
import sys
import json
import os
import time
import requests
from pathlib import Path
from dotenv import load_dotenv
import pandas as pd
from neo4j import GraphDatabase

PROJECT_ROOT = Path(os.getcwd()).parent.parent if 'notebooks' in str(Path(os.getcwd())) else Path(os.getcwd())
sys.path.insert(0, str(PROJECT_ROOT))
os.chdir(PROJECT_ROOT)
load_dotenv()

print(f'Project root: {PROJECT_ROOT}')
# Out:
# Project root: d:\TA\llm-driven-legal-kg-visualization

# %% [markdown]
# ## Step 0: Configuration
#
# Set `EXPERIMENT_ID`, backend URL, dan sumber test data.
#
# **Experiment ID format:** `Q2C_{NUMBER}`

# %%
# === Configuration ===
EXPERIMENT_ID = "Q2C_012"              # Unique ID per eksperimen
DOCUMENT_IDS = ["POJK_11_2022", "UU_11_2008", "UU_19_2016"]          # doc_ids untuk query (list)

# Backend API
BACKEND_URL = "http://localhost:8000"   # Backend FastAPI base URL
API_TIMEOUT = 120                       # Timeout per request (seconds)
DELAY_BETWEEN_REQUESTS = 1              # Delay antar request (seconds)

# Sumber test data: 'csv' atau 'gsheets'
TEST_DATA_SOURCE = "gsheets"
CSV_PATH = "HOTS_Q2C_TEST_DATA.csv"              # Jika source = csv
GSHEETS_SHEET_NAME = "HOTS_Q2C_TEST_DATA_V3"   # Jika source = gsheets

# Tulis hasil ke Google Sheets?
WRITE_TO_GSHEETS = False
EXPERIMENT_SHEET_NAME = f"EXP_E2E_{GSHEETS_SHEET_NAME}_{'_'.join(DOCUMENT_IDS)}"    # 1 sheet per eksperimen

print(f'Experiment: {EXPERIMENT_ID}')
print(f'Document IDs: {DOCUMENT_IDS}')
print(f'Backend: {BACKEND_URL}')
print(f'Test data source: {TEST_DATA_SOURCE}')
print(f'Output sheet: {EXPERIMENT_SHEET_NAME}')
# Out:
# Experiment: Q2C_012
# Document IDs: ['POJK_11_2022', 'UU_11_2008', 'UU_19_2016']
# Backend: http://localhost:8000
# Test data source: gsheets
# Output sheet: EXP_E2E_HOTS_Q2C_TEST_DATA_V3_POJK_11_2022_UU_11_2008_UU_19_2016

# %% [markdown]
# ## Step 1: Load Test Data

# %%
# === Load Test Data ===
if TEST_DATA_SOURCE == "gsheets":
    from modules.google_sheets_utils import GoogleUtil
    gu = GoogleUtil(
        private_key=os.getenv('GOOGLE_SHEETS_PRIVATE_KEY', ''),
        client_email=os.getenv('GOOGLE_SHEETS_CLIENT_EMAIL', '')
    )
    spreadsheet_id = os.getenv('GOOGLE_SPREADSHEET_ID', '')
    test_df = gu.load_dataframe_from_sheet(spreadsheet_id, GSHEETS_SHEET_NAME)
else:
    # Look in project root, parent directory, or data directory
    if os.path.exists(CSV_PATH):
        test_df = pd.read_csv(CSV_PATH)
    elif os.path.exists(PROJECT_ROOT / CSV_PATH):
        test_df = pd.read_csv(PROJECT_ROOT / CSV_PATH)
    else:
        test_df = pd.read_csv(PROJECT_ROOT.parent / CSV_PATH)

print(f'Loaded {len(test_df)} test cases')
print(f'Columns: {list(test_df.columns)}')
test_df[['TEST_ID', 'CATEGORY', 'QUESTION']].head(5)
# Out:
# 2026-06-02 07:10:34,416 - INFO - Retrieving worksheet 'HOTS_Q2C_TEST_DATA_V3' from spreadsheet ID '1oN5kMN_OI8WyITAQgJ3-S_0GlzraXug8p2tMKSmq7u0'...
# 2026-06-02 07:10:36,660 - INFO - Successfully loaded 100 rows from worksheet 'HOTS_Q2C_TEST_DATA_V3'.
# Loaded 100 test cases
# Columns: ['TEST_ID', 'QUESTION', 'CATEGORY', 'EXPECTED_CYPHER_QUERY', 'EXPECTED_QUERY_RESULT', 'FORMATTED_EXPECTED_QUERY_RESULT']
#     TEST_ID         CATEGORY  \
# 0  HOTS_001     akses_ilegal
# 1  HOTS_002      tata_kelola
# 2  HOTS_003  eskalasi_sanksi
# 3  HOTS_004     akses_ilegal
# 4  HOTS_005      tata_kelola
#
#                                             QUESTION
# 0  Apakah dilarang menyebarkan informasi elektron...
# 1  Siapakah saja yang paling sedikit harus menjad...
# 2  Apakah sanksi administratif bagi bank umum yan...
# 3  Dalam Pasal 34 ayat (1) UU Nomor 11 Tahun 2008...
# 4  Apakah individu atau masyarakat diperbolehkan ...

# %% [markdown]
# ## Step 2: Verify Backend is Running

# %%
# === Check Backend Health ===
try:
    resp = requests.get(f"{BACKEND_URL}/docs", timeout=5)
    print(f'✅ Backend is running at {BACKEND_URL} (status: {resp.status_code})')
except Exception as e:
    print(f'❌ Backend not reachable: {e}')
    print('Make sure to run: uvicorn app.main:app --reload --port 8000')
# Out:
# ✅ Backend is running at http://localhost:8000 (status: 200)

# %%
# === Connect to Neo4j (for re-executing generated Cypher) ===
NEO4J_URI = os.getenv('NEO4J_URI', 'bolt://localhost:7687')
NEO4J_USER = os.getenv('NEO4J_USER', 'neo4j')
NEO4J_PASSWORD = os.getenv('NEO4J_PASSWORD', '')
NEO4J_DATABASE = os.getenv('NEO4J_DATABASE', 'neo4j')

driver = GraphDatabase.driver(NEO4J_URI, auth=(NEO4J_USER, NEO4J_PASSWORD))

# Test connection
with driver.session(database=NEO4J_DATABASE) as session:
    result = session.run('RETURN 1 AS test')
    print(f'✅ Connected to Neo4j database: "{NEO4J_DATABASE}"')
# Out:
# ✅ Connected to Neo4j database: "experiment-2"

# %% [markdown]
# ## Step 3: Define E2E Evaluation Logic

# %%
def call_qa_api(question: str, doc_ids: list, backend_url: str, timeout: int = 120) -> dict:
    """Call the /api/qa endpoint and extract all response fields.
    
    Returns:
        dict with keys: status, cypher, cypher_result, answer, error, time_s,
                        references, process_steps
    """
    start = time.time()
    try:
        resp = requests.post(
            f"{backend_url}/api/qa",
            json={"question": question, "doc_ids": doc_ids},
            timeout=timeout,
        )
        elapsed = time.time() - start
        
        if resp.status_code != 200:
            return {
                'status': 'HTTP_ERROR',
                'cypher': '',
                'cypher_result': '',
                'answer': '',
                'error': f'HTTP {resp.status_code}: {resp.text[:200]}',
                'time_s': round(elapsed, 2),
                'references': '',
                'process_steps': [],
            }
        
        data = resp.json()
        steps = data.get('process_steps', [])
        answer = data.get('answer', '')
        cypher = data.get('cypher_query', '')
        
        # Extract Cypher Query Result from process_steps
        # Step 3 = Neo4j execution result (contains 'detail' and 'data')
        cypher_result_detail = ''
        cypher_result_data = []
        for s in steps:
            if s.get('step') == 3:
                cypher_result_detail = s.get('detail', '')
                cypher_result_data = s.get('data', [])
                break
        
        # Format cypher result: combine detail + raw data
        if cypher_result_data:
            cypher_result = json.dumps(cypher_result_data, ensure_ascii=False)
        else:
            cypher_result = cypher_result_detail
        
        # Determine status
        cypher_ok = any(s.get('step') == 2 and s.get('status') == 'done' for s in steps)
        has_results = 'hasil ditemukan' in cypher_result_detail and not cypher_result_detail.startswith('0')
        has_answer = bool(answer) and len(answer) > 20
        
        if cypher_ok and has_results and has_answer:
            status = 'PASS'
        elif cypher_ok and not has_results:
            status = 'FAIL'
        elif not cypher_ok:
            status = 'FAIL'
        else:
            status = 'PARTIAL'
        
        # Extract metadata
        references = '; '.join(data.get('references', []))
        
        return {
            'status': status,
            'cypher': cypher,
            'cypher_result': cypher_result,
            'cypher_result_detail': cypher_result_detail,
            'answer': answer,
            'time_s': round(elapsed, 2),
            'references': references,
            'process_steps': steps,
        }
        
    except requests.exceptions.Timeout:
        return {
            'status': 'ERROR',
            'cypher': '',
            'cypher_result': '',
            'cypher_result_detail': '',
            'answer': '',
            'error': f'Timeout ({timeout}s)',
            'time_s': timeout,
            'references': '',
            'process_steps': [],
        }
    except Exception as e:
        elapsed = time.time() - start
        return {
            'status': 'ERROR',
            'cypher': '',
            'cypher_result': '',
            'cypher_result_detail': '',
            'answer': '',
            'error': str(e),
            'time_s': round(elapsed, 2),
            'references': '',
            'process_steps': [],
        }


print('✅ E2E evaluation functions defined')


def execute_cypher_on_neo4j(cypher_query: str) -> list:
    """Re-execute a Cypher query directly on Neo4j and return JSON results."""
    if not cypher_query or not cypher_query.strip():
        return []
    try:
        with driver.session(database=NEO4J_DATABASE) as session:
            result = session.run(cypher_query)
            records = [dict(record) for record in result]
            return records
    except Exception as e:
        return [{'error': str(e)}]


print('✅ Neo4j re-execution helper defined')
# Out:
# ✅ E2E evaluation functions defined
# ✅ Neo4j re-execution helper defined

# %% [markdown]
# ## Step 4: Run E2E Evaluation

# %%
# === Run All Test Cases ===
import os
results = []
total = len(test_df)

# Create real-time log file path
os.makedirs('data/evaluation', exist_ok=True)
log_file_path = f'data/evaluation/e2e_eval_log_{EXPERIMENT_ID}.txt'

# Initialize log file
with open(log_file_path, 'w', encoding='utf-8') as log_f:
    log_f.write(f"=== Q2C Evaluation Log: {EXPERIMENT_ID} ===\n")
    log_f.write(f"Documents: {', '.join(DOCUMENT_IDS)}\n")
    log_f.write(f"Backend: {BACKEND_URL}\n")
    log_f.write("="*80 + "\n\n")

print(f"Real-time evaluation logs will be written to: {log_file_path}\n")

for idx, row in test_df.iterrows():
    test_id = row['TEST_ID']
    question = row['QUESTION']
    
    print(f"[{idx+1}/{total}] {test_id}: {question}")
    
    # Call backend API
    result = call_qa_api(
        question=question,
        doc_ids=DOCUMENT_IDS,
        backend_url=BACKEND_URL,
        timeout=API_TIMEOUT,
    )
    
    # Print status
    status_icon = {'PASS': '✅', 'FAIL': '❌', 'ERROR': '⚠️', 'PARTIAL': '🟡'}.get(result['status'], '❓')
    print(f"    Status: {status_icon} {result['status']} ({result['time_s']:.1f}s)")
    
    # Print FULL Cypher Query
    if result['cypher']:
        print("    Generated Cypher:")
        print("    " + "-"*80)
        for line in result['cypher'].splitlines():
            print(f"    {line}")
        print("    " + "-"*80)
    
    # === RE-EXECUTE generated Cypher directly on Neo4j ===
    cypher_json_result = []
    formatted_cypher_result = ''
    if result['cypher']:
        cypher_json_result = execute_cypher_on_neo4j(result['cypher'])
        if cypher_json_result:
            formatted_cypher_result = json.dumps(cypher_json_result, indent=2, ensure_ascii=False)
            print(f"    Neo4j Query Result: {len(cypher_json_result)} records returned")
            print("    " + "-"*80)
            # Show first 50 lines of formatted JSON
            lines = formatted_cypher_result.splitlines()
            for line in lines[:50]:
                print(f"    {line}")
            if len(lines) > 50:
                print(f"    ... ({len(lines) - 50} more lines)")
            print("    " + "-"*80)
        else:
            print("    Neo4j Query Result: 0 records (empty)")
    
    # Print original backend result detail
    if result.get('cypher_result_detail', ''):
        print(f"    Backend Result Detail: {result['cypher_result_detail']}")
        
    # Print FULL LLM Answer
    if result['answer']:
        print("    Final LLM Answer:")
        print("    " + "-"*80)
        for line in result['answer'].splitlines():
            print(f"    {line}")
        print("    " + "-"*80)
        
    print("\n" + "="*100 + "\n")
    
    # Write to log file in real time
    with open(log_file_path, 'a', encoding='utf-8') as log_f:
        log_f.write(f"[{idx+1}/{total}] {test_id}: {question}\n")
        log_f.write(f"Status: {result['status']} ({result['time_s']:.1f}s)\n")
        if result['cypher']:
            log_f.write(f"Generated Cypher:\n{result['cypher']}\n")
        if formatted_cypher_result:
            log_f.write(f"Cypher Query Result ({len(cypher_json_result)} records):\n{formatted_cypher_result}\n")
        if result['answer']:
            log_f.write(f"LLM Answer:\n{result['answer']}\n")
        if result.get('error', ''):
            log_f.write(f"Error:\n{result['error']}\n")
        log_f.write("-" * 80 + "\n\n")
    
    # Build result row
    results.append({
        'TEST_ID': test_id,
        'QUESTION': question,
        'GENERATED_CYPHER': result['cypher'],
        'CYPHER_QUERY_RESULT': json.dumps(cypher_json_result, ensure_ascii=False) if cypher_json_result else '',
        'FORMATTED_CYPHER_QUERY_RESULT': formatted_cypher_result,
        'ANSWER': result['answer'],
        'STATUS': result['status'],
        'REFERENCES': result['references'],
        'TIME_S': result['time_s'],
    })
    
    # Delay between requests
    if idx < total - 1:
        time.sleep(DELAY_BETWEEN_REQUESTS)

results_df = pd.DataFrame(results)
print(f'\n=== Done: {len(results)} test cases evaluated ===')
# Out:
# Real-time evaluation logs will be written to: data/evaluation/e2e_eval_log_Q2C_012.txt
#
# [1/100] HOTS_001: Apakah dilarang menyebarkan informasi elektronik yang bermuatan penghinaan dan/atau pencemaran nama baik, dan berapa sanksi pidana maksimalnya berdasarkan UU ITE?
#     Status: ✅ PASS (37.9s)
#     Generated Cypher:
#     --------------------------------------------------------------------------------
#     MATCH (prohibition_ayat)-[:MENGATUR]->(ph:PerbuatanHukum) WHERE prohibition_ayat.source_document_id = 'UU_11_2008' AND prohibition_ayat.label CONTAINS 'Pasal 27' AND (toLower(ph.label) CONTAINS 'penghinaan' OR toLower(ph.label) CONTAINS 'pencemaran nama baik') OPTIONAL MATCH (sanction_ayat)-[:MERUJUK]->(prohibition_ayat) WHERE sanction_ayat.source_document_id = 'UU_11_2008' OPTIONAL MATCH (sanction_ayat)-[:MENETAPKAN_SANKSI]->(sk:Sanksi) RETURN prohibition_ayat.label AS pasal_larangan, ph.label AS perbuatan_dilarang, sk.label AS sanksi_pidana, prohibition_ayat.source_document_id AS regulasi LIMIT 100
#     --------------------------------------------------------------------------------
#     Neo4j Query Result: 1 records returned
#     --------------------------------------------------------------------------------
#     [
#       {
#         "pasal_larangan": "Pasal 27 ayat (3)",
#         "perbuatan_dilarang": "mendistribusikan dan/atau mentransmisikan dan/atau membuat dapat diaksesnya Informasi Elektronik dan/atau Dokumen Elektronik yang memiliki muatan penghinaan dan/atau pencemaran nama baik",
#         "sanksi_pidana": "pidana penjara paling lama 6 (enam) tahun dan/atau denda paling banyak Rp1.000.000.000,00 (satu miliar rupiah)",
#         "regulasi": "UU_11_2008"
#       }
#     ]
#     --------------------------------------------------------------------------------
#     Backend Result Detail: 1 hasil ditemukan
#     Final LLM Answer:
#     --------------------------------------------------------------------------------
#     Berdasarkan UU No. 11 Tahun 2008 tentang Informasi dan Transaksi Elektronik (UU ITE), dilarang untuk menyebarkan informasi elektronik yang bermuatan penghinaan dan/atau pencemaran nama baik.
#
#     Larangan ini diatur dalam **Pasal 27 ayat (3)**, yang menyatakan bahwa setiap Orang dilarang mendistribusikan dan/atau mentransmisikan dan/atau membuat dapat diaksesnya Informasi Elektronik dan/atau Dokumen Elektronik yang memiliki muatan penghinaan dan/atau pencemaran nama baik.
#
#     Sanksi pidana maksimal untuk perbuatan tersebut adalah **pidana penjara paling lama 6 (enam) tahun dan/atau denda paling banyak Rp1.000.000.000,00 (satu miliar rupiah)**.
#     --------------------------------------------------------------------------------
#
# ====================================================================================================
#
# [2/100] HOTS_002: Siapakah saja yang paling sedikit harus menjadi anggota Komite Pengarah TI bank umum menurut Pasal 7 ayat (3) POJK 11/2022?
#     Status: ✅ PASS (11.3s)
#     Generated Cypher:
#     --------------------------------------------------------------------------------
#     MATCH (a:Ayat)-[:BERLAKU_UNTUK]->(e:EntitasHukum) WHERE a.source_document_id = 'POJK_11_2022' AND a.label CONTAINS 'Pasal 7 ayat (3)' RETURN a.label AS pasal_ayat, a.content AS isi_ayat, e.label AS entitas, a.source_document_id AS regulasi LIMIT 100
#     --------------------------------------------------------------------------------
#     Neo4j Query Result: 5 records returned
#     --------------------------------------------------------------------------------
#     [
#       {
#         "pasal_ayat": "Pasal 7 ayat (3)",
#         "isi_ayat": "Komite pengarah TI sebagaimana dimaksud pada\nayat (1) paling sedikit beranggotakan:\na. direktur yang membawahkan satuan kerja\npenyelenggara TI;\nb. direktur yang membawahkan satuan kerja\nmanajemen risiko;\nc. pejabat tertinggi yang memimpin satuan kerja\npenyelenggara TI; dan\nd. pejabat tertinggi yang memimpin satuan kerja\npengguna TI.",
#         "entitas": "Komite pengarah TI",
#         "regulasi": "POJK_11_2022"
#       },
#       {
#         "pasal_ayat": "Pasal 7 ayat (3)",
#         "isi_ayat": "Komite pengarah TI sebagaimana dimaksud pada\nayat (1) paling sedikit beranggotakan:\na. direktur yang membawahkan satuan kerja\npenyelenggara TI;\nb. direktur yang membawahkan satuan kerja\nmanajemen risiko;\nc. pejabat tertinggi yang memimpin satuan kerja\npenyelenggara TI; dan\nd. pejabat tertinggi yang memimpin satuan kerja\npengguna TI.",
#         "entitas": "direktur yang membawahkan satuan kerja penyelenggara TI",
#         "regulasi": "POJK_11_2022"
#       },
#       {
#         "pasal_ayat": "Pasal 7 ayat (3)",
#         "isi_ayat": "Komite pengarah TI sebagaimana dimaksud pada\nayat (1) paling sedikit beranggotakan:\na. direktur yang membawahkan satuan kerja\npenyelenggara TI;\nb. direktur yang membawahkan satuan kerja\nmanajemen risiko;\nc. pejabat tertinggi yang memimpin satuan kerja\npenyelenggara TI; dan\nd. pejabat tertinggi yang memimpin satuan kerja\npengguna TI.",
#         "entitas": "direktur yang membawahkan satuan kerja manajemen risiko",
#         "regulasi": "POJK_11_2022"
#       },
#       {
#         "pasal_ayat": "Pasal 7 ayat (3)",
#         "isi_ayat": "Komite pengarah TI sebagaimana dimaksud pada\nayat (1) paling sedikit beranggotakan:\na. direktur yang membawahkan satuan kerja\npenyelenggara TI;\nb. direktur yang membawahkan satuan kerja\nmanajemen risiko;\nc. pejabat tertinggi yang memimpin satuan kerja\npenyelenggara TI; dan\nd. pejabat tertinggi yang memimpin satuan kerja\npengguna TI.",
#         "entitas": "pejabat tertinggi yang memimpin satuan kerja penyelenggara TI",
#         "regulasi": "POJK_11_2022"
#       },
#       {
#         "pasal_ayat": "Pasal 7 ayat (3)",
#         "isi_ayat": "Komite pengarah TI sebagaimana dimaksud pada\nayat (1) paling sedikit beranggotakan:\na. direktur yang membawahkan satuan kerja\npenyelenggara TI;\nb. direktur yang membawahkan satuan kerja\nmanajemen risiko;\nc. pejabat tertinggi yang memimpin satuan kerja\npenyelenggara TI; dan\nd. pejabat tertinggi yang memimpin satuan kerja\npengguna TI.",
#         "entitas": "pejabat tertinggi yang memimpin satuan kerja pengguna TI",
#         "regulasi": "POJK_11_2022"
#       }
#     ]
#     --------------------------------------------------------------------------------
#     Backend Result Detail: 5 hasil ditemukan
#     Final LLM Answer:
#     --------------------------------------------------------------------------------
#     Menurut POJK No. 11/POJK.03/2022, Pasal 7 ayat (3) mengatur bahwa Komite pengarah TI paling sedikit beranggotakan:
#     a. direktur yang membawahkan satuan kerja penyelenggara TI;
#     b. direktur yang membawahkan satuan kerja manajemen risiko;
#     c. pejabat tertinggi yang memimpin satuan kerja penyelenggara TI; dan
#     d. pejabat tertinggi yang memimpin satuan kerja pengguna TI.
#     --------------------------------------------------------------------------------
#
# ====================================================================================================
#
# [3/100] HOTS_003: Apakah sanksi administratif bagi bank umum yang melanggar ketentuan tata kelola TI dan tidak menindaklanjuti teguran tertulis pertama menurut Pasal 9 POJK 11/2022?
#     Status: ❌ FAIL (22.0s)
#     Generated Cypher:
#     --------------------------------------------------------------------------------
#     MATCH (target)
#     WHERE (target:Pasal OR target:Ayat)
#       AND target.source_document_id = 'POJK_11_2022'
#       AND target.label CONTAINS 'Pasal 9'
#     MATCH (a:Ayat)-[:MERUJUK]->(target), (a)-[:MENETAPKAN_SANKSI]->(sk:Sanksi)
#     WHERE a.source_document_id = 'POJK_11_2022'
#       AND toLower(sk.label) CONTAINS 'sanksi administratif'
#       AND toLower(a.content) CONTAINS 'bank umum'
#       AND toLower(a.content) CONTAINS 'tata kelola ti'
#       AND toLower(a.content) CONTAINS 'teguran tertulis pertama'
#     RETURN a.label AS pasal_sanksi, a.content AS isi_pasal_sanksi, sk.label AS sanksi_detail, a.source_document_id AS regulasi
#     LIMIT 100
#     --------------------------------------------------------------------------------
#     Neo4j Query Result: 0 records (empty)
#     Backend Result Detail: Tidak ada hasil
#     Final LLM Answer:
#     --------------------------------------------------------------------------------
#     Menurut POJK No. 11/POJK.03/2022 tentang Penyelenggaraan Teknologi Informasi oleh Bank Umum, Pasal 9 ayat (2) mengatur bahwa dalam hal Bank telah dikenai sanksi administratif berupa teguran tertulis sebagaimana dimaksud pada ayat (1) dan belum memenuhi ketentuan yang dilanggar, Bank akan dikenai sanksi administratif berupa:
#     a. larangan untuk menerbitkan produk Bank baru;
#     b. pembekuan kegiatan usaha tertentu; dan/atau
#     c. penurunan penilaian faktor tata kelola dalam penilaian tingkat kesehatan Bank.
#     --------------------------------------------------------------------------------
#
# ====================================================================================================
#
# [4/100] HOTS_004: Dalam Pasal 34 ayat (1) UU Nomor 11 Tahun 2008, terdapat larangan memproduksi atau mendistribusikan perangkat keras atau lunak untuk memfasilitasi perbuatan dalam Pasal 27 sampai Pasal 33. Apa bunyi dari ketentuan Pasal 34 ayat (1) tersebut?
#     Status: ✅ PASS (10.8s)
#     Generated Cypher:
#     --------------------------------------------------------------------------------
#     MATCH (a:Ayat) WHERE toLower(a.label) = 'pasal 34 ayat (1)' AND a.source_document_id = 'UU_11_2008' RETURN a.label AS ayat, a.content AS isi, a.source_document_id AS regulasi LIMIT 100
#     --------------------------------------------------------------------------------
#     Neo4j Query Result: 1 records returned
#     --------------------------------------------------------------------------------
#     [
#       {
#         "ayat": "Pasal 34 ayat (1)",
#         "isi": "Setiap Orang dengan sengaja dan tanpa hak atau melawan hukum memproduksi, menjual, mengadakan untuk digunakan, mengimpor, mendistribusikan, menyediakan, atau memiliki:\na. perangkat keras atau perangkat lunak Komputer yang dirancang atau secara khusus dikembangkan untuk memfasilitasi perbuatan sebagaimana dimaksud dalam Pasal 27 sampai dengan Pasal 33;\nb. sandi lewat Komputer, Kode Akses, atau hal yang sejenis dengan itu yang ditujukan agar Sistem Elektronik menjadi dapat diakses dengan tujuan memfasilitasi perbuatan sebagaimana dimaksud dalam Pasal 27 sampai dengan Pasal 33.",
#         "regulasi": "UU_11_2008"
#       }
#     ]
#     --------------------------------------------------------------------------------
#     Backend Result Detail: 1 hasil ditemukan
#     Final LLM Answer:
#     --------------------------------------------------------------------------------
#     Menurut UU No. 11 Tahun 2008 tentang Informasi dan Transaksi Elektronik (UU ITE), bunyi dari Pasal 34 ayat (1) adalah sebagai berikut:
#
#     **Pasal 34 ayat (1)**
#     "Setiap Orang dengan sengaja dan tanpa hak atau melawan hukum memproduksi, menjual, mengadakan untuk digunakan, mengimpor, mendistribusikan, menyediakan, atau memiliki:
#     a. perangkat keras atau perangkat lunak Komputer yang dirancang atau secara khusus dikembangkan untuk memfasilitasi perbuatan sebagaimana dimaksud dalam Pasal 27 sampai dengan Pasal 33;
#     b. sandi lewat Komputer, Kode Akses, atau hal yang sejenis dengan itu yang ditujukan agar Sistem Elektronik menjadi dapat diakses dengan tujuan memfasilitasi perbuatan sebagaimana dimaksud dalam Pasal 27 sampai dengan Pasal 33."
#     --------------------------------------------------------------------------------
#
# ====================================================================================================
#
# [5/100] HOTS_005: Apakah individu atau masyarakat diperbolehkan mengelola nama domain sendiri menurut Pasal 24 ayat (1) UU Nomor 11 Tahun 2008?
#     Status: ✅ PASS (15.6s)
#     Generated Cypher:
#     --------------------------------------------------------------------------------
#     MATCH (a:Ayat) WHERE a.source_document_id = 'UU_11_2008' AND a.label CONTAINS 'Pasal 24 ayat (1)' OPTIONAL MATCH (a)-[:BERLAKU_UNTUK]->(e:EntitasHukum) WHERE e.source_document_id = 'UU_11_2008' RETURN a.label AS pasal_ayat, a.content AS isi_ketentuan, e.label AS berlaku_untuk, a.source_document_id AS regulasi LIMIT 100
#     --------------------------------------------------------------------------------
#     Neo4j Query Result: 2 records returned
#     --------------------------------------------------------------------------------
#     [
#       {
#         "pasal_ayat": "Pasal 24 ayat (1)",
#         "isi_ketentuan": "Pengelola Nama Domain adalah Pemerintah dan/atau masyarakat.",
#         "berlaku_untuk": "masyarakat",
#         "regulasi": "UU_11_2008"
#       },
#       {
#         "pasal_ayat": "Pasal 24 ayat (1)",
#         "isi_ketentuan": "Pengelola Nama Domain adalah Pemerintah dan/atau masyarakat.",
#         "berlaku_untuk": "Pemerintah",
#         "regulasi": "UU_11_2008"
#       }
#     ]
#     --------------------------------------------------------------------------------
#     Backend Result Detail: 2 hasil ditemukan
#     Final LLM Answer:
#     --------------------------------------------------------------------------------
#     Menurut UU No. 11 Tahun 2008 tentang Informasi dan Transaksi Elektronik, Pasal 24 ayat (1) menyatakan bahwa Pengelola Nama Domain adalah Pemerintah dan/atau masyarakat. Ini berarti individu atau masyarakat diperbolehkan mengelola nama domain sendiri.
#     --------------------------------------------------------------------------------
#
# ====================================================================================================
#
# [6/100] HOTS_006: Apakah semua bentuk surat atau dokumen elektronik dapat dijadikan alat bukti yang sah di pengadilan menurut Pasal 5 ayat (4) UU ITE?
#     Status: ✅ PASS (13.9s)
#     Generated Cypher:
#     --------------------------------------------------------------------------------
#     MATCH (a:Ayat) WHERE toLower(a.label) = 'pasal 5 ayat (4)' AND a.source_document_id IN ['UU_11_2008', 'UU_19_2016'] RETURN a.label AS ayat, a.content AS isi, a.source_document_id AS regulasi LIMIT 1
#     --------------------------------------------------------------------------------
#     Neo4j Query Result: 1 records returned
#     --------------------------------------------------------------------------------
#     [
#       {
#         "ayat": "Pasal 5 ayat (4)",
#         "isi": "Ketentuan mengenai Informasi Elektronik dan/atau Dokumen Elektronik sebagaimana dimaksud pada ayat (1) tidak berlaku untuk:\na. surat yang menurut Undang-Undang harus dibuat dalam bentuk tertulis; dan\nb. surat beserta dokumennya yang menurut Undang- Undang harus dibuat dalam bentuk akta notaril atau akta yang dibuat oleh pejabat pembuat akta.",
#         "regulasi": "UU_11_2008"
#       }
#     ]
#     --------------------------------------------------------------------------------
#     Backend Result Detail: 1 hasil ditemukan
#     Final LLM Answer:
#     --------------------------------------------------------------------------------
#     Menurut UU No. 11 Tahun 2008 tentang Informasi dan Transaksi Elektronik (UU ITE), tidak semua bentuk surat atau dokumen elektronik dapat dijadikan alat bukti yang sah di pengadilan.
#
#     Berdasarkan **Pasal 5 ayat (4)**, ketentuan mengenai Informasi Elektronik dan/atau Dokumen Elektronik sebagai alat bukti hukum yang sah sebagaimana dimaksud pada ayat (1) tidak berlaku untuk:
#     a. surat yang menurut Undang-Undang harus dibuat dalam bentuk tertulis; dan
#     b. surat beserta dokumennya yang menurut Undang-Undang harus dibuat dalam bentuk akta notaril atau akta yang dibuat oleh pejabat pembuat akta.
#
#     Pasal 5 secara keseluruhan menyatakan bahwa Informasi Elektronik dan/atau Dokumen Elektronik dan/atau hasil cetaknya merupakan alat bukti hukum yang sah, merupakan perluasan dari alat bukti yang sah sesuai dengan Hukum Acara yang berlaku di Indonesia, dan dinyatakan sah apabila menggunakan Sistem Elektronik sesuai dengan ketentuan yang diatur dalam Undang-Undang ini. Namun, pengecualian di ayat (4) tersebut membatasi jenis surat atau dokumen elektronik yang dapat dijadikan alat bukti.
#
#     UU No. 19 Tahun 2016 tentang Perubahan atas UU ITE menyatakan bahwa ketentuan Pasal 5 tetap berlaku dengan perubahan penjelasan ayat (1) dan ayat (2). Ini berarti isi Pasal 5 ayat (4) tidak mengalami perubahan.
#     --------------------------------------------------------------------------------
#
# ====================================================================================================
#
# [7/100] HOTS_007: Pemerintah memutus akses (blocking) ke sebuah situs web portal berita independen secara sepihak karena dianggap menyebarkan informasi provokatif. Pihak pengelola situs menuntut karena tidak ada surat peringatan terlebih dahulu. Bagaimana wewenang pemerintah dalam pemutusan akses konten dilarang menurut UU ITE hasil amandemen 2016?
#     Status: ✅ PASS (35.9s)
#     Generated Cypher:
#     --------------------------------------------------------------------------------
#     MATCH (n) WHERE n.source_document_id = 'UU_19_2016' AND (n:Pasal OR n:Ayat) AND toLower(n.content) CONTAINS 'pemutusan akses' AND toLower(n.content) CONTAINS 'pemerintah' RETURN n.label AS pasal_ayat, n.content AS isi, n.source_document_id AS regulasi LIMIT 100
#     --------------------------------------------------------------------------------
#     Neo4j Query Result: 2 records returned
#     --------------------------------------------------------------------------------
#     [
#       {
#         "pasal_ayat": "Pasal 40",
#         "isi": "Ketentuan Pasal 40 diubah sehingga berbunyi:\n(1) Pemerintah memfasilitasi pemanfaatan Teknologi Informasi dan Transaksi Elektronik sesuai dengan ketentuan peraturan perundang-undangan.\n(2) Pemerintah melindungi kepentingan umum dari segala jenis gangguan sebagai akibat penyalahgunaan Informasi Elektronik dan Transaksi Elektronik yang mengganggu ketertiban umum, sesuai dengan ketentuan peraturan perundang-undangan.\n(2a) Pemerintah wajib melakukan pencegahan penyebarluasan dan penggunaan Informasi Elektronik dan/atau Dokumen Elektronik yang memiliki muatan yang dilarang sesuai dengan ketentuan peraturan perundang-undangan.\n(2b) Dalam melakukan pencegahan sebagaimana dimaksud pada ayat (2a), Pemerintah berwenang melakukan pemutusan akses dan/atau memerintahkan kepada Penyelenggara Sistem Elektronik untuk melakukan pemutusan akses terhadap Informasi Elektronik dan/atau Dokumen Elektronik yang memiliki muatan yang melanggar hukum.\n(3) Pemerintah menetapkan instansi atau institusi yang memiliki data elektronik strategis yang wajib dilindungi.\n(4) Instansi atau institusi sebagaimana dimaksud pada ayat (3) harus membuat Dokumen Elektronik dan rekam cadang elektroniknya serta menghubungkannya ke pusat data tertentu untuk kepentingan pengamanan data.\n(5) Instansi atau institusi lain selain diatur pada ayat (3) membuat Dokumen Elektronik dan rekam cadang elektroniknya sesuai dengan keperluan perlindungan data yang dimilikinya.\n(6) Ketentuan lebih lanjut mengenai peran Pemerintah sebagaimana dimaksud pada ayat (1), ayat (2), ayat (2a), ayat (2b), dan ayat (3) diatur dalam peraturan pemerintah.",
#         "regulasi": "UU_19_2016"
#       },
#       {
#         "pasal_ayat": "Pasal 40 ayat (2b)",
#         "isi": "Dalam melakukan pencegahan s6lagaimana\ndimaksud pada ayat (2a), Pemerintah berwenang\nmelakukan pemutusan akses dan/atau\nmemerintahkan kepada Penyelenggara Sistem\nElektronik untuk melakukan pemutusan akses\nterhadap Informasi Elektronik dan/ atau Dokumen\nElektronik yang memiliki muatan yang melanggar\nhukum.",
#         "regulasi": "UU_19_2016"
#       }
#     ]
#     --------------------------------------------------------------------------------
#     Backend Result Detail: 2 hasil ditemukan
#     Final LLM Answer:
#     --------------------------------------------------------------------------------
#     Menurut UU No. 19 Tahun 2016 tentang Perubahan atas UU ITE, wewenang pemerintah dalam pemutusan akses konten yang dilarang diatur dalam Pasal 40.
#
#     Pasal 40 menyatakan bahwa:
#     *   Pemerintah wajib melakukan pencegahan penyebarluasan dan penggunaan Informasi Elektronik dan/atau Dokumen Elektronik yang memiliki muatan yang dilarang sesuai dengan ketentuan peraturan perundang-undangan, sebagaimana diatur dalam Pasal 40 ayat (2a).
#     *   Dalam melakukan pencegahan tersebut, Pemerintah berwenang melakukan pemutusan akses dan/atau memerintahkan kepada Penyelenggara Sistem Elektronik untuk melakukan pemutusan akses terhadap Informasi Elektronik dan/atau Dokumen Elektronik yang memiliki muatan yang melanggar hukum, sebagaimana diatur dalam Pasal 40 ayat (2b).
#
#     Lebih lanjut, ketentuan mengenai peran Pemerintah sebagaimana dimaksud pada ayat (1), ayat (2), ayat (2a), ayat (2b), dan ayat (3) akan diatur dalam peraturan pemerintah, sesuai dengan Pasal 40 ayat (6).
#     --------------------------------------------------------------------------------
#
# ====================================================================================================
#
# [8/100] HOTS_008: Apakah pemilikan dan penggunaan nama domain di Indonesia harus didasarkan pada iktikad baik menurut ketentuan Pasal 23 ayat (2) UU ITE?
#     Status: ✅ PASS (16.2s)
#     Generated Cypher:
#     --------------------------------------------------------------------------------
#     MATCH (a:Ayat) WHERE toLower(a.label) = 'pasal 23 ayat (2)' AND a.source_document_id IN ['UU_11_2008', 'UU_19_2016'] RETURN a.label AS ayat, a.content AS isi, a.source_document_id AS regulasi LIMIT 1
#     --------------------------------------------------------------------------------
#     Neo4j Query Result: 1 records returned
#     --------------------------------------------------------------------------------
#     [
#       {
#         "ayat": "Pasal 23 ayat (2)",
#         "isi": "Pemilikan dan penggunaan Nama Domain sebagaimana dimaksud pada ayat (1) harus didasarkan pada iktikad baik, tidak melanggar prinsip persaingan usaha secara sehat, dan tidak melanggar hak Orang lain.",
#         "regulasi": "UU_11_2008"
#       }
#     ]
#     --------------------------------------------------------------------------------
#     Backend Result Detail: 1 hasil ditemukan
#     Final LLM Answer:
#     --------------------------------------------------------------------------------
#     Ya, berdasarkan ketentuan dalam UU No. 11 Tahun 2008 tentang Informasi dan Transaksi Elektronik (UU ITE), pemilikan dan penggunaan Nama Domain harus didasarkan pada iktikad baik.
#
#     Menurut **Pasal 23 ayat (2) UU No. 11 Tahun 2008**, "Pemilikan dan penggunaan Nama Domain sebagaimana dimaksud pada ayat (1) harus didasarkan pada iktikad baik, tidak melanggar prinsip persaingan usaha secara sehat, dan tidak melanggar hak Orang lain."
#     --------------------------------------------------------------------------------
#
# ====================================================================================================
#
# [9/100] HOTS_009: Sebuah korporasi secara sengaja menyebarkan informasi bohong di internet yang mengakibatkan kerugian materiil bagi jutaan konsumen digital. Bagaimana mekanisme penjatuhan sanksi pidana jika pelaku kejahatan siber tersebut berbentuk korporasi menurut UU ITE?
#     Status: ✅ PASS (27.6s)
#     Generated Cypher:
#     --------------------------------------------------------------------------------
#     MATCH (p:Pasal)
#     WHERE p.source_document_id IN ['UU_11_2008', 'UU_19_2016']
#       AND (toLower(p.content) CONTAINS 'korporasi' OR toLower(p.label) CONTAINS 'korporasi')
#       AND (toLower(p.content) CONTAINS 'pidana' OR toLower(p.content) CONTAINS 'sanksi' OR toLower(p.content) CONTAINS 'tanggung jawab')
#     OPTIONAL MATCH (p)-[:MEMILIKI_AYAT]->(a:Ayat)
#     RETURN p.label AS pasal, p.content AS isi_pasal, a.label AS ayat, a.content AS isi_ayat, p.source_document_id AS regulasi
#     ORDER BY p.label, a.label
#     LIMIT 100
#     --------------------------------------------------------------------------------
#     Neo4j Query Result: 4 records returned
#     --------------------------------------------------------------------------------
#     [
#       {
#         "pasal": "Pasal 52",
#         "isi_pasal": "(1) Dalam hal tindak pidana sebagaimana dimaksud dalam Pasal 27 ayat (1) menyangkut kesusilaan atau eksploitasi seksual terhadap anak dikenakan pemberatan sepertiga dari pidana pokok.\n(2) Dalam hal perbuatan sebagaimana dimaksud dalam Pasal\n30 sampai dengan Pasal 37 ditujukan terhadap Komputer dan/atau Sistem Elektronik serta Informasi Elektronik dan/atau Dokumen Elektronik milik Pemerintah dan/atau yang digunakan untuk layanan publik dipidana dengan pidana pokok ditambah sepertiga.\n(3) Dalam hal perbuatan sebagaimana dimaksud dalam Pasal\n30 sampai dengan Pasal 37 ditujukan terhadap Komputer dan/atau Sistem Elektronik serta Informasi Elektronik dan/atau Dokumen Elektronik milik Pemerintah dan/atau badan strategis termasuk dan tidak terbatas pada lembaga pertahanan, bank sentral, perbankan, keuangan, lembaga internasional, otoritas penerbangan diancam dengan pidana maksimal ancaman pidana pokok masing-masing Pasal ditambah dua pertiga.\n(4) Dalam hal tindak pidana sebagaimana dimaksud dalam Pasal 27 sampai dengan Pasal 37 dilakukan oleh korporasi dipidana dengan pidana pokok ditambah dua pertiga.",
#         "ayat": "Pasal 52 ayat (1)",
#         "isi_ayat": "Dalam hal tindak pidana sebagaimana dimaksud dalam Pasal 27 ayat (1) menyangkut kesusilaan atau eksploitasi seksual terhadap anak dikenakan pemberatan sepertiga dari pidana pokok.",
#         "regulasi": "UU_11_2008"
#       },
#       {
#         "pasal": "Pasal 52",
#         "isi_pasal": "(1) Dalam hal tindak pidana sebagaimana dimaksud dalam Pasal 27 ayat (1) menyangkut kesusilaan atau eksploitasi seksual terhadap anak dikenakan pemberatan sepertiga dari pidana pokok.\n(2) Dalam hal perbuatan sebagaimana dimaksud dalam Pasal\n30 sampai dengan Pasal 37 ditujukan terhadap Komputer dan/atau Sistem Elektronik serta Informasi Elektronik dan/atau Dokumen Elektronik milik Pemerintah dan/atau yang digunakan untuk layanan publik dipidana dengan pidana pokok ditambah sepertiga.\n(3) Dalam hal perbuatan sebagaimana dimaksud dalam Pasal\n30 sampai dengan Pasal 37 ditujukan terhadap Komputer dan/atau Sistem Elektronik serta Informasi Elektronik dan/atau Dokumen Elektronik milik Pemerintah dan/atau badan strategis termasuk dan tidak terbatas pada lembaga pertahanan, bank sentral, perbankan, keuangan, lembaga internasional, otoritas penerbangan diancam dengan pidana maksimal ancaman pidana pokok masing-masing Pasal ditambah dua pertiga.\n(4) Dalam hal tindak pidana sebagaimana dimaksud dalam Pasal 27 sampai dengan Pasal 37 dilakukan oleh korporasi dipidana dengan pidana pokok ditambah dua pertiga.",
#         "ayat": "Pasal 52 ayat (2)",
#         "isi_ayat": "Dalam hal perbuatan sebagaimana dimaksud dalam Pasal 30 sampai dengan Pasal 37 ditujukan terhadap Komputer dan/atau Sistem Elektronik serta Informasi Elektronik dan/atau Dokumen Elektronik milik Pemerintah dan/atau yang digunakan untuk layanan publik dipidana dengan pidana pokok ditambah sepertiga.",
#         "regulasi": "UU_11_2008"
#       },
#       {
#         "pasal": "Pasal 52",
#         "isi_pasal": "(1) Dalam hal tindak pidana sebagaimana dimaksud dalam Pasal 27 ayat (1) menyangkut kesusilaan atau eksploitasi seksual terhadap anak dikenakan pemberatan sepertiga dari pidana pokok.\n(2) Dalam hal perbuatan sebagaimana dimaksud dalam Pasal\n30 sampai dengan Pasal 37 ditujukan terhadap Komputer dan/atau Sistem Elektronik serta Informasi Elektronik dan/atau Dokumen Elektronik milik Pemerintah dan/atau yang digunakan untuk layanan publik dipidana dengan pidana pokok ditambah sepertiga.\n(3) Dalam hal perbuatan sebagaimana dimaksud dalam Pasal\n30 sampai dengan Pasal 37 ditujukan terhadap Komputer dan/atau Sistem Elektronik serta Informasi Elektronik dan/atau Dokumen Elektronik milik Pemerintah dan/atau badan strategis termasuk dan tidak terbatas pada lembaga pertahanan, bank sentral, perbankan, keuangan, lembaga internasional, otoritas penerbangan diancam dengan pidana maksimal ancaman pidana pokok masing-masing Pasal ditambah dua pertiga.\n(4) Dalam hal tindak pidana sebagaimana dimaksud dalam Pasal 27 sampai dengan Pasal 37 dilakukan oleh korporasi dipidana dengan pidana pokok ditambah dua pertiga.",
#         "ayat": "Pasal 52 ayat (3)",
#         "isi_ayat": "Dalam hal perbuatan sebagaimana dimaksud dalam Pasal 30 sampai dengan Pasal 37 ditujukan terhadap Komputer dan/atau Sistem Elektronik serta Informasi Elektronik dan/atau Dokumen Elektronik milik Pemerintah dan/atau badan strategis termasuk dan tidak terbatas pada lembaga pertahanan, bank sentral, perbankan, keuangan, lembaga internasional, otoritas penerbangan diancam dengan pidana maksimal ancaman pidana pokok masing-masing Pasal ditambah dua pertiga.",
#         "regulasi": "UU_11_2008"
#       },
#       {
#         "pasal": "Pasal 52",
#         "isi_pasal": "(1) Dalam hal tindak pidana sebagaimana dimaksud dalam Pasal 27 ayat (1) menyangkut kesusilaan atau eksploitasi seksual terhadap anak dikenakan pemberatan sepertiga dari pidana pokok.\n(2) Dalam hal perbuatan sebagaimana dimaksud dalam Pasal\n30 sampai dengan Pasal 37 ditujukan terhadap Komputer dan/atau Sistem Elektronik serta Informasi Elektronik dan/atau Dokumen Elektronik milik Pemerintah dan/atau yang digunakan untuk layanan publik dipidana dengan pidana pokok ditambah sepertiga.\n(3) Dalam hal perbuatan sebagaimana dimaksud dalam Pasal\n30 sampai dengan Pasal 37 ditujukan terhadap Komputer dan/atau Sistem Elektronik serta Informasi Elektronik dan/atau Dokumen Elektronik milik Pemerintah dan/atau badan strategis termasuk dan tidak terbatas pada lembaga pertahanan, bank sentral, perbankan, keuangan, lembaga internasional, otoritas penerbangan diancam dengan pidana maksimal ancaman pidana pokok masing-masing Pasal ditambah dua pertiga.\n(4) Dalam hal tindak pidana sebagaimana dimaksud dalam Pasal 27 sampai dengan Pasal 37 dilakukan oleh korporasi dipidana dengan pidana pokok ditambah dua pertiga.",
#         "ayat": "Pasal 52 ayat (4)",
#         "isi_ayat": "Dalam hal tindak pidana sebagaimana dimaksud dalam Pasal 27 sampai dengan Pasal 37 dilakukan oleh korporasi dipidana dengan pidana pokok ditambah dua pertiga.",
#         "regulasi": "UU_11_2008"
#       }
#     ]
#     --------------------------------------------------------------------------------
#     Backend Result Detail: 4 hasil ditemukan
#     Final LLM Answer:
#     --------------------------------------------------------------------------------
#     Menurut UU No. 11 Tahun 2008 tentang Informasi dan Transaksi Elektronik (UU ITE) dan perubahannya UU No. 19 Tahun 2016, mekanisme penjatuhan sanksi pidana jika pelaku kejahatan siber berbentuk korporasi adalah sebagai berikut:
#
#     Perbuatan menyebarkan informasi bohong di internet yang mengakibatkan kerugian materiil bagi jutaan konsumen digital diatur dalam Pasal 28 ayat (1). Tindak pidana yang diatur dalam Pasal 28 ayat (1) ini dikenakan sanksi pidana berdasarkan Pasal 45A ayat (1) UU No. 19 Tahun 2016 tentang Perubahan atas UU ITE. Untuk informasi lebih lanjut mengenai pidana pokok yang diatur dalam Pasal 45A ayat (1), silakan ajukan pertanyaan tersendiri.
#
#     Mengenai mekanisme penjatuhan sanksi pidana jika tindak pidana tersebut dilakukan oleh korporasi, Pasal 52 ayat (4) UU No. 11 Tahun 2008 menyatakan:
#     "Dalam hal tindak pidana sebagaimana dimaksud dalam Pasal 27 sampai dengan Pasal 37 dilakukan oleh korporasi dipidana dengan pidana pokok ditambah dua pertiga."
#
#     Dengan demikian, jika tindak pidana penyebaran informasi bohong yang mengakibatkan kerugian konsumen (sebagaimana diatur dalam Pasal 28 ayat (1) yang termasuk dalam rentang Pasal 27 sampai dengan Pasal 37) dilakukan oleh korporasi, maka korporasi tersebut akan dipidana dengan pidana pokok yang seharusnya dikenakan untuk perbuatan tersebut, ditambah dua pertiga dari pidana pokok tersebut.
#     --------------------------------------------------------------------------------
#
# ====================================================================================================
#
# [10/100] HOTS_010: Bank X mendirikan divisi baru untuk mengelola aplikasi mobile banking mereka, namun hanya dipimpin oleh seorang Manajer IT tanpa pengawasan Komite Pengarah TI karena alasan efisiensi anggaran. Apakah hal ini diperbolehkan menurut tata kelola TI dalam POJK 11/2022?
#     Status: ✅ PASS (22.2s)
#     Generated Cypher:
#     --------------------------------------------------------------------------------
#     MATCH (n) WHERE n.source_document_id = 'POJK_11_2022' AND (n:Pasal OR n:Ayat) AND (toLower(n.content) CONTAINS 'tata kelola ti' OR toLower(n.content) CONTAINS 'komite pengarah ti' OR toLower(n.content) CONTAINS 'pengawasan' OR toLower(n.content) CONTAINS 'direksi' OR toLower(n.content) CONTAINS 'dewan komisaris') RETURN n.label AS pasal_ayat, n.content AS isi, n.source_document_id AS regulasi ORDER BY n.label LIMIT 100
#     --------------------------------------------------------------------------------
#     Neo4j Query Result: 37 records returned
#     --------------------------------------------------------------------------------
#     [
#       {
#         "pasal_ayat": "Pasal 1",
#         "isi": "Dalam Peraturan Otoritas Jasa Keuangan ini, yang\ndimaksud dengan:\n1. Bank Umum yang selanjutnya disebut sebagai Bank\nadalah bank yang melaksanakan kegiatan usaha secara\nkonvensional atau melaksanakan kegiatan usaha\nberdasarkan prinsip syariah, yang dalam kegiatannya\nmemberikan jasa dalam lalu lintas pembayaran,\ntermasuk kantor cabang dari bank yang berkedudukan\ndi luar negeri dan unit usaha syariah.\n2. Teknologi Informasi yang selanjutnya disingkat TI\nadalah suatu teknik untuk mengumpulkan,\nmenyiapkan, menyimpan, memproses, mengumumkan,\nmenganalisis, dan/atau menyebarkan informasi.\n3. Sistem Elektronik adalah serangkaian perangkat dan\nprosedur elektronik yang berfungsi mempersiapkan,\nmengumpulkan, mengolah, menganalisis, menyimpan,\nmenampilkan, mengumumkan, mengirimkan,\ndan/atau menyebarkan informasi elektronik.\n4. Pusat Data adalah suatu fasilitas yang digunakan\nuntuk menempatkan Sistem Elektronik dan komponen\nterkaitnya untuk keperluan penempatan,\npenyimpanan, dan pengolahan data.\n5. Pusat Pemulihan Bencana adalah suatu fasilitas yang\ndigunakan untuk memulihkan kembali data atau\ninformasi serta fungsi penting Sistem Elektronik yang\nterganggu atau rusak akibat terjadinya bencana yang\ndisebabkan oleh alam atau manusia.\n6. Rencana Pemulihan Bencana adalah dokumen yang\nberisikan rencana dan langkah untuk menggantikan\ndan/atau memulihkan kembali akses data, perangkat\nkeras, dan perangkat lunak yang diperlukan, agar Bank\ndapat menjalankan kegiatan operasional bisnis yang\nkritikal setelah adanya gangguan dan/atau bencana.\n7. Direksi adalah organ Bank yang berwenang dan\nbertanggung jawab penuh atas pengurusan Bank\nuntuk kepentingan Bank, sesuai dengan maksud dan\ntujuan Bank serta mewakili Bank, baik di dalam\nmaupun di luar pengadilan sesuai dengan anggaran\ndasar bagi Bank yang berbadan hukum perseroan\nterbatas, organ atau pihak yang setara bagi Bank\ndengan bentuk badan hukum selain perseroan\nterbatas, atau pemimpin kantor cabang dan pejabat\nsatu tingkat di bawah pemimpin kantor cabang bagi\nkantor cabang dari bank yang berkedudukan di luar\nnegeri.\n8. Dewan Komisaris adalah organ Bank yang bertugas\nmelakukan pengawasan secara umum dan/atau\nkhusus sesuai dengan anggaran dasar serta memberi\nnasihat kepada Direksi bagi Bank yang berbadan\nhukum perseroan terbatas, organ atau pihak yang\nsetara bagi Bank dengan bentuk badan hukum selain\nperseroan terbatas, atau pihak yang ditunjuk untuk\nmelaksanakan fungsi pengawasan bagi kantor cabang\ndari bank yang berkedudukan di luar negeri.",
#         "regulasi": "POJK_11_2022"
#       },
#       {
#         "pasal_ayat": "Pasal 10",
#         "isi": "Ketentuan lebih lanjut mengenai penerapan tata kelola TI\nditetapkan oleh Otoritas Jasa Keuangan.",
#         "regulasi": "POJK_11_2022"
#       },
#       {
#         "pasal_ayat": "Pasal 11",
#         "isi": "(1) Bank wajib memiliki arsitektur TI.\n(2) Dalam menyusun arsitektur TI sebagaimana dimaksud\npada ayat (1), Bank mempertimbangkan faktor paling\nsedikit:\na. visi dan misi Bank;\nb. rencana korporasi Bank;\nc. proses dan kapabilitas bisnis Bank;\nd. tata kelola TI;\ne. prinsip pengelolaan data, aplikasi, dan teknologi\nBank;\nf. ukuran dan kompleksitas bisnis Bank;\ng. kemampuan permodalan Bank;\nh. standar yang berlaku secara nasional maupun\ninternasional; dan\ni. ketentuan peraturan perundang-undangan.\n(3) Arsitektur TI sebagaimana dimaksud pada ayat (1)\ndisusun secara komprehensif meliputi proses:\na. perencanaan;\nb. desain;\nc. implementasi; dan\nd. kontrol.\n(4) Dalam hal terdapat perubahan pada faktor\nsebagaimana dimaksud pada ayat (2), Bank wajib\nmelakukan penginian terhadap arsitektur TI.\n(5) Ketentuan lebih lanjut mengenai penyusunan\narsitektur TI ditetapkan oleh Otoritas Jasa Keuangan.",
#         "regulasi": "POJK_11_2022"
#       },
#       {
#         "pasal_ayat": "Pasal 11 ayat (2)",
#         "isi": "Dalam menyusun arsitektur TI sebagaimana dimaksud\npada ayat (1), Bank mempertimbangkan faktor paling\nsedikit:\na. visi dan misi Bank;\nb. rencana korporasi Bank;\nc. proses dan kapabilitas bisnis Bank;\nd. tata kelola TI;\ne. prinsip pengelolaan data, aplikasi, dan teknologi\nBank;\nf. ukuran dan kompleksitas bisnis Bank;\ng. kemampuan permodalan Bank;\nh. standar yang berlaku secara nasional maupun\ninternasional; dan\ni. ketentuan peraturan perundang-undangan.",
#         "regulasi": "POJK_11_2022"
#       },
#       {
#         "pasal_ayat": "Pasal 2",
#         "isi": "(1) Bank wajib menerapkan tata kelola TI yang baik dalam\npenyelenggaraan TI.\n(2) Dalam menerapkan tata kelola TI yang baik\nsebagaimana dimaksud pada ayat (1), Bank\nmempertimbangkan faktor paling sedikit:\na. strategi dan tujuan bisnis Bank;\nb. ukuran dan kompleksitas bisnis Bank;\nc. peran TI bagi Bank;\nd. metode pengadaan sumber daya TI;\ne. risiko dan permasalahan terkait TI;\nf. praktik atau standar yang berlaku secara nasional\nmaupun internasional; dan\ng. ketentuan peraturan perundang-undangan.\n(3) Dalam menerapkan tata kelola TI yang baik\nsebagaimana dimaksud pada ayat (1), Bank melakukan\nkegiatan paling sedikit:\na. evaluasi atas pilihan strategi, pengarahan atas\nstrategi penyelenggaraan TI, dan pemantauan\npencapaian strategi;\nb. penyelarasan, perencanaan, dan pengorganisasian\nseluruh unit, strategi, dan kegiatan yang\nmendukung penyelenggaraan TI;\nc. pendefinisian, akuisisi, dan implementasi atas\nsolusi TI serta integrasinya dalam proses bisnis\nBank;\nd. penyediaan dukungan operasional layanan TI\nkepada pemangku kepentingan; dan\ne. pemantauan kinerja dan kesesuaian\npenyelenggaraan TI dengan target kinerja intern,\npengendalian intern, dan ketentuan peraturan\nperundang-undangan.\n(4) Penerapan tata kelola TI yang baik sebagaimana\ndimaksud pada ayat (1) berlaku bagi seluruh unit\ndan/atau fungsi:\na. pengelola TI; dan\nb. pengguna TI,\npada Bank.",
#         "regulasi": "POJK_11_2022"
#       },
#       {
#         "pasal_ayat": "Pasal 2 ayat (1)",
#         "isi": "Bank wajib menerapkan tata kelola TI yang baik dalam\npenyelenggaraan TI.",
#         "regulasi": "POJK_11_2022"
#       },
#       {
#         "pasal_ayat": "Pasal 2 ayat (2)",
#         "isi": "Dalam menerapkan tata kelola TI yang baik\nsebagaimana dimaksud pada ayat (1), Bank\nmempertimbangkan faktor paling sedikit:\na. strategi dan tujuan bisnis Bank;\nb. ukuran dan kompleksitas bisnis Bank;\nc. peran TI bagi Bank;\nd. metode pengadaan sumber daya TI;\ne. risiko dan permasalahan terkait TI;\nf. praktik atau standar yang berlaku secara nasional\nmaupun internasional; dan\ng. ketentuan peraturan perundang-undangan.",
#         "regulasi": "POJK_11_2022"
#       },
#       {
#         "pasal_ayat": "Pasal 2 ayat (3)",
#         "isi": "Dalam menerapkan tata kelola TI yang baik\nsebagaimana dimaksud pada ayat (1), Bank melakukan\nkegiatan paling sedikit:\na. evaluasi atas pilihan strategi, pengarahan atas\nstrategi penyelenggaraan TI, dan pemantauan\npencapaian strategi;\nb. penyelarasan, perencanaan, dan pengorganisasian\nseluruh unit, strategi, dan kegiatan yang\nmendukung penyelenggaraan TI;\nc. pendefinisian, akuisisi, dan implementasi atas\nsolusi TI serta integrasinya dalam proses bisnis\nBank;\nd. penyediaan dukungan operasional layanan TI\nkepada pemangku kepentingan; dan\ne. pemantauan kinerja dan kesesuaian\npenyelenggaraan TI dengan target kinerja intern,\npengendalian intern, dan ketentuan peraturan\nperundang-undangan.",
#         "regulasi": "POJK_11_2022"
#       },
#       {
#         "pasal_ayat": "Pasal 2 ayat (4)",
#         "isi": "Penerapan tata kelola TI yang baik sebagaimana\ndimaksud pada ayat (1) berlaku bagi seluruh unit\ndan/atau fungsi:\na. pengelola TI; dan\nb. pengguna TI,\npada Bank.",
#         "regulasi": "POJK_11_2022"
#       },
#       {
#         "pasal_ayat": "Pasal 29",
#         "isi": "(1) Bank dapat menggunakan pihak penyedia jasa TI dalam\npenyelenggaraan TI.\n(2) Bank yang menggunakan pihak penyedia jasa TI\nsebagaimana dimaksud pada ayat (1) wajib memiliki\nkemampuan dalam melakukan pengawasan atas\npelaksanaan kegiatan Bank yang diselenggarakan oleh\npihak penyedia jasa TI.\n(3) Bank wajib memiliki kebijakan dan prosedur dalam\npenggunaan pihak penyedia jasa TI sebagaimana\ndimaksud pada ayat (1) paling sedikit memuat:\na. proses identifikasi kebutuhan penggunaan pihak\npenyedia jasa TI;\nb. proses pemilihan pihak penyedia jasa TI;\nc. tata cara melakukan hubungan kerja sama dengan\npihak penyedia jasa TI;\nd. proses manajemen risiko penggunaan pihak\npenyedia jasa TI; dan\ne. tata cara penilaian kinerja dan kepatuhan pihak\npenyedia jasa TI.",
#         "regulasi": "POJK_11_2022"
#     ... (137 more lines)
#     --------------------------------------------------------------------------------
#     Backend Result Detail: 37 hasil ditemukan
#     Final LLM Answer:
#     --------------------------------------------------------------------------------
#     Berdasarkan POJK No. 11/POJK.03/2022 tentang Penyelenggaraan Teknologi Informasi oleh Bank Umum, tindakan Bank X yang mendirikan divisi baru untuk mengelola aplikasi mobile banking tanpa pengawasan Komite Pengarah TI **tidak diperbolehkan**.
#
#     Menurut POJK No. 11/POJK.03/2022:
#     *   **Pasal 7 ayat (1)** secara tegas menyatakan bahwa "Bank wajib memiliki komite pengarah TI."
#     *   **Pasal 7 ayat (2)** menjelaskan bahwa Komite Pengarah TI bertanggung jawab memberikan rekomendasi kepada Direksi paling sedikit terkait dengan:
#         *   rencana strategis TI yang sejalan dengan rencana korporasi Bank;
#         *   kebijakan, standar, dan prosedur TI;
#         *   kesesuaian antara rencana pengembangan TI dan rencana strategis TI;
#         *   kesesuaian antara pelaksanaan pengembangan TI dan rencana pengembangan TI;
#         *   evaluasi atas efektivitas biaya TI terhadap pencapaian manfaat yang direncanakan;
#         *   pemantauan atas kinerja TI dan upaya peningkatan kinerja TI;
#         *   upaya penyelesaian berbagai masalah terkait TI yang tidak dapat diselesaikan oleh satuan kerja pengguna dan penyelenggara TI secara efektif, efisien, dan tepat waktu; dan
#         *   kecukupan dan alokasi sumber daya terkait TI yang dimiliki Bank.
#     *   **Pasal 7 ayat (3)** juga mengatur bahwa Komite Pengarah TI paling sedikit beranggotakan direktur yang membawahkan satuan kerja penyelenggara TI, direktur yang membawahkan satuan kerja manajemen risiko, pejabat tertinggi yang memimpin satuan kerja penyelenggara TI, dan pejabat tertinggi yang memimpin satuan kerja pengguna TI. Komite ini diketuai oleh salah satu direktur Bank merangkap sebagai anggota, sebagaimana diatur dalam **Pasal 7 ayat (4)**.
#
#     Dengan demikian, keberadaan Komite Pengarah TI adalah suatu kewajiban bagi Bank dalam menerapkan tata kelola TI yang baik, dan perannya sangat penting dalam memberikan rekomendasi serta pengawasan terhadap berbagai aspek penyelenggaraan TI, termasuk pengembangan aplikasi mobile banking. Alasan efisiensi anggaran tidak dapat membatalkan kewajiban ini.
#     --------------------------------------------------------------------------------
#
# ====================================================================================================
#
# [11/100] HOTS_011: Bank D ingin menyediakan jasa infrastruktur komputasi awan (cloud sharing) miliknya kepada sebuah startup fintech P2P Lending independen yang bukan bagian dari grup usaha bank. Apakah penyediaan jasa TI ini diperbolehkan menurut POJK 11/2022?
#     Status: ❌ FAIL (42.4s)
#     Generated Cypher:
#     --------------------------------------------------------------------------------
#     MATCH (n) WHERE n.source_document_id = 'POJK_11_2022' AND (n:Pasal OR n:Ayat) AND toLower(n.content) CONTAINS 'komputasi awan' AND toLower(n.content) CONTAINS 'bank' AND (toLower(n.content) CONTAINS 'penyediaan' OR toLower(n.content) CONTAINS 'jasa') AND (toLower(n.content) CONTAINS 'pihak lain' OR toLower(n.content) CONTAINS 'pihak ketiga') AND toLower(n.content) CONTAINS 'teknologi informasi' OPTIONAL MATCH (n)-[:BERLAKU_UNTUK]->(e:EntitasHukum) RETURN n.label AS pasal_ayat, n.content AS isi, COLLECT(e.label) AS berlaku_untuk, n.source_document_id AS regulasi LIMIT 100
#     --------------------------------------------------------------------------------
#     Neo4j Query Result: 0 records (empty)
#     Backend Result Detail: Tidak ada hasil
#     Final LLM Answer:
#     --------------------------------------------------------------------------------
#     Menurut POJK No. 11/POJK.03/2022 tentang Penyelenggaraan Teknologi Informasi oleh Bank Umum, penyediaan jasa infrastruktur komputasi awan (cloud sharing) oleh Bank D kepada startup fintech P2P Lending independen yang bukan bagian dari grup usaha bank memiliki ketentuan yang perlu diperhatikan, terutama terkait apakah "jasa infrastruktur komputasi awan (cloud sharing)" termasuk dalam kategori "jasa TI berupa aplikasi".
#
#     Berikut adalah penjelasannya berdasarkan Pasal 48 POJK No. 11/POJK.03/2022:
#
#     **1. Jika "jasa infrastruktur komputasi awan (cloud sharing)" dianggap sebagai "jasa TI berupa aplikasi":**
#     *   **Pasal 48 ayat (4)** menyatakan bahwa penyediaan jasa TI berupa aplikasi kepada lembaga jasa keuangan selain bank dapat dilakukan sepanjang:
#         *   a. lembaga jasa keuangan pengguna jasa TI berada dalam satu grup atau kelompok dengan Bank; **dan**
#         *   b. penggunaan aplikasi ditujukan untuk mendukung kegiatan operasional yang umum.
#     *   Mengingat startup fintech P2P Lending yang disebutkan **bukan bagian dari grup usaha bank**, maka syarat pada Pasal 48 ayat (4) huruf a tidak terpenuhi. Oleh karena itu, jika jasa infrastruktur komputasi awan dianggap sebagai jasa TI berupa aplikasi, maka penyediaan jasa tersebut **tidak diperbolehkan**.
#
#     **2. Jika "jasa infrastruktur komputasi awan (cloud sharing)" tidak dianggap sebagai "jasa TI berupa aplikasi":**
#     *   Maka ketentuan umum Pasal 48 ayat (1), (2), dan (3) akan berlaku:
#         *   **Pasal 48 ayat (1)**: Bank hanya dapat menyediakan jasa TI kepada lembaga jasa keuangan lain yang diawasi oleh Otoritas Jasa Keuangan. Jika startup fintech P2P Lending tersebut diawasi OJK, maka syarat ini terpenuhi.
#         *   **Pasal 48 ayat (3)**: Bank wajib memperoleh izin Otoritas Jasa Keuangan untuk setiap rencana penyediaan jasa TI tersebut.
#         *   **Pasal 48 ayat (2)**: Bank juga wajib memenuhi persyaratan, yaitu:
#             *   a. penyediaan jasa TI tidak menjadi salah satu kegiatan pokok Bank;
#             *   b. memenuhi prinsip kehati-hatian;
#             *   c. memperhatikan analisis biaya dan manfaat;
#             *   d. memenuhi prinsip hubungan kerja sama secara wajar; dan
#             *   e. memenuhi ketentuan peraturan perundang-undangan.
# ...
#     *   Sebelum perubahan, **Pasal 43 ayat (6) UU No. 11 Tahun 2008** secara spesifik mengatur bahwa "Dalam hal melakukan penangkapan dan penahanan, penyidik melalui penuntut umum wajib meminta penetapan ketua pengadilan negeri setempat dalam waktu satu kali dua puluh empat jam."
#
#     Dengan demikian, UU No. 19 Tahun 2016 telah mengubah ketentuan mengenai penangkapan dan penahanan oleh PPNS, yang semula memiliki batas waktu spesifik 1x24 jam untuk meminta penetapan ketua pengadilan negeri, menjadi merujuk sepenuhnya pada "ketentuan hukum acara pidana".
#
#     Untuk menentukan sah atau tidaknya penahanan selama 48 jam secara sepihak oleh PPNS, perlu merujuk pada ketentuan hukum acara pidana yang berlaku. Informasi mengenai detail ketentuan hukum acara pidana terkait batas waktu penahanan tidak termuat dalam data yang diberikan. Untuk informasi lebih lanjut mengenai ketentuan hukum acara pidana terkait batas waktu penahanan, silakan ajukan pertanyaan tersendiri.
#     --------------------------------------------------------------------------------
#
# ====================================================================================================
#
# [96/100] HOTS_096: Apakah kriteria sistem elektronik bank umum yang dapat ditempatkan di luar wilayah Indonesia menurut Pasal 35 ayat (3) POJK 11/2022?
#     Status: ✅ PASS (8.7s)
#     Generated Cypher:
#     --------------------------------------------------------------------------------
#     MATCH (a:Ayat)
#     WHERE a.source_document_id = 'POJK_11_2022' AND toLower(a.label) = 'pasal 35 ayat (3)'
#     RETURN a.label AS ayat, a.content AS isi, a.source_document_id AS regulasi
#     LIMIT 1
#     --------------------------------------------------------------------------------
#     Neo4j Query Result: 1 records returned
#     --------------------------------------------------------------------------------
#     [
#       {
#         "ayat": "Pasal 35 ayat (3)",
#         "isi": "Kriteria Sistem Elektronik yang dapat ditempatkan\npada Pusat Data dan/atau Pusat Pemulihan Bencana\ndi luar wilayah Indonesia sebagaimana dimaksud pada\nayat (2), meliputi:\na. Sistem Elektronik yang digunakan untuk\nmendukung analisis terintegrasi dalam memenuhi\nketentuan yang diterbitkan oleh otoritas negara\nasal Bank yang bersifat global, termasuk lintas\nnegara;\nb. Sistem Elektronik yang digunakan untuk\nmanajemen risiko secara terintegrasi dengan\nkantor pusat Bank atau kantor induk atau kantor\nentitas utama di luar wilayah Indonesia;\nc. Sistem Elektronik yang digunakan untuk\npenerapan anti pencucian uang dan pencegahan\npendanaan terorisme secara terintegrasi dengan\nkantor pusat Bank atau kantor induk Bank di luar\nwilayah Indonesia;\nd. Sistem Elektronik yang digunakan untuk\npelayanan kepada nasabah secara global, yang\nmemerlukan integrasi dengan Sistem Elektronik\nmilik grup Bank di luar wilayah Indonesia;\ne. Sistem Elektronik yang digunakan untuk\nmanajemen komunikasi antara kantor pusat Bank\ndan kantor cabang, atau antara perusahaan anak\ndan perusahaan induk; dan/atau\nf. Sistem Elektronik yang digunakan untuk\nmanajemen intern Bank.",
#         "regulasi": "POJK_11_2022"
#       }
#     ]
#     --------------------------------------------------------------------------------
#     Backend Result Detail: 1 hasil ditemukan
#     Final LLM Answer:
#     --------------------------------------------------------------------------------
#     Menurut POJK No. 11/POJK.03/2022, Pasal 35 ayat (3) menetapkan kriteria Sistem Elektronik yang dapat ditempatkan pada Pusat Data dan/atau Pusat Pemulihan Bencana di luar wilayah Indonesia, yaitu meliputi:
#     a. Sistem Elektronik yang digunakan untuk mendukung analisis terintegrasi dalam memenuhi ketentuan yang diterbitkan oleh otoritas negara asal Bank yang bersifat global, termasuk lintas negara;
#     b. Sistem Elektronik yang digunakan untuk manajemen risiko secara terintegrasi dengan kantor pusat Bank atau kantor induk atau kantor entitas utama di luar wilayah Indonesia;
#     c. Sistem Elektronik yang digunakan untuk penerapan anti pencucian uang dan pencegahan pendanaan terorisme secara terintegrasi dengan kantor pusat Bank atau kantor induk Bank di luar wilayah Indonesia;
#     d. Sistem Elektronik yang digunakan untuk pelayanan kepada nasabah secara global, yang memerlukan integrasi dengan Sistem Elektronik milik grup Bank di luar wilayah Indonesia;
#     e. Sistem Elektronik yang digunakan untuk manajemen komunikasi antara kantor pusat Bank dan kantor cabang, atau antara perusahaan anak dan perusahaan induk; dan/atau
#     f. Sistem Elektronik yang digunakan untuk manajemen intern Bank.
#     --------------------------------------------------------------------------------
#
# ====================================================================================================
#
# [97/100] HOTS_097: Apakah kedudukan informasi elektronik dan/atau dokumen elektronik hasil cetaknya merupakan alat bukti hukum yang sah di persidangan menurut Pasal 5 ayat (1) UU ITE?
#     Status: ✅ PASS (20.2s)
#     Generated Cypher:
#     --------------------------------------------------------------------------------
#     MATCH (a:Ayat)
#     WHERE a.source_document_id IN ['UU_11_2008', 'UU_19_2016']
#       AND toLower(a.label) CONTAINS 'pasal 5 ayat (1)'
#     RETURN a.label AS pasal_ayat, a.content AS isi, a.source_document_id AS regulasi, a.jenis_perubahan AS jenis_perubahan
#     ORDER BY a.source_document_id DESC
#     LIMIT 100
#     --------------------------------------------------------------------------------
#     Neo4j Query Result: 1 records returned
#     --------------------------------------------------------------------------------
#     [
#       {
#         "pasal_ayat": "Pasal 5 ayat (1)",
#         "isi": "Informasi Elektronik dan/atau Dokumen Elektronik dan/atau hasil cetaknya merupakan alat bukti hukum yang sah.",
#         "regulasi": "UU_11_2008",
#         "jenis_perubahan": null
#       }
#     ]
#     --------------------------------------------------------------------------------
#     Backend Result Detail: 1 hasil ditemukan
#     Final LLM Answer:
#     --------------------------------------------------------------------------------
#     Menurut UU No. 11 Tahun 2008 tentang Informasi dan Transaksi Elektronik (UU ITE), kedudukan Informasi Elektronik dan/atau Dokumen Elektronik hasil cetaknya merupakan alat bukti hukum yang sah di persidangan.
#
#     Berikut adalah rinciannya:
#
#     **Menurut UU No. 11 Tahun 2008 tentang Informasi dan Transaksi Elektronik (UU ITE):**
#     *   **Pasal 5 ayat (1)** menyatakan bahwa Informasi Elektronik dan/atau Dokumen Elektronik dan/atau hasil cetaknya merupakan alat bukti hukum yang sah.
#     *   **Pasal 5 ayat (2)** lebih lanjut menjelaskan bahwa Informasi Elektronik dan/atau Dokumen Elektronik dan/atau hasil cetaknya sebagaimana dimaksud pada ayat (1) merupakan perluasan dari alat bukti yang sah sesuai dengan Hukum Acara yang berlaku di Indonesia.
#     *   **Pasal 5 ayat (3)** menambahkan bahwa Informasi Elektronik dan/atau Dokumen Elektronik dinyatakan sah apabila menggunakan Sistem Elektronik sesuai dengan ketentuan yang diatur dalam Undang-Undang ini.
#     *   **Pasal 44** menegaskan bahwa alat bukti penyidikan, penuntutan, dan pemeriksaan di sidang pengadilan menurut Undang-Undang ini adalah alat bukti sebagaimana dimaksud dalam ketentuan Perundang-undangan dan alat bukti lain berupa Informasi Elektronik dan/atau Dokumen Elektronik sebagaimana dimaksud dalam Pasal 1 angka 1 dan angka 4 serta Pasal 5 ayat (1), ayat (2), dan ayat (3).
#
#     **Menurut UU No. 19 Tahun 2016 tentang Perubahan atas UU ITE:**
#     *   Ketentuan Pasal 5 tetap, namun terdapat perubahan penjelasan ayat (1) dan ayat (2) sehingga penjelasan Pasal 5 menjadi sebagaimana ditetapkan dalam penjelasan pasal demi pasal Undang-Undang ini.
#     --------------------------------------------------------------------------------
#
# ====================================================================================================
#
# [98/100] HOTS_098: Jika OJK menemukan pelanggaran berulang oleh Bank terkait pemenuhan standar ketahanan siber dan bank tetap tidak menindaklanjuti teguran tertulis pertama, eskalasi sanksi administratif apa yang paling berat yang dapat dijatuhkan oleh OJK?
#     Status: ❌ FAIL (27.6s)
#     Generated Cypher:
#     --------------------------------------------------------------------------------
#     MATCH (a:Ayat)-[:MENETAPKAN_SANKSI]->(s:Sanksi)
#     WHERE a.source_document_id = 'POJK_11_2022' AND s.source_document_id = 'POJK_11_2022'
#       AND toLower(a.content) CONTAINS 'pelanggaran'
#       AND toLower(a.content) CONTAINS 'berulang'
#       AND toLower(a.content) CONTAINS 'ketahanan siber'
#       AND toLower(a.content) CONTAINS 'teguran tertulis'
#       AND toLower(a.content) CONTAINS 'tidak menindaklanjuti'
#       AND toLower(s.label) CONTAINS 'sanksi administratif'
#       AND (toLower(s.label) CONTAINS 'pencabutan' OR toLower(s.label) CONTAINS 'pembekuan')
#     RETURN a.label AS pasal_ayat, a.content AS isi_ketentuan, s.label AS sanksi, s.content AS detail_sanksi, a.source_document_id AS regulasi
#     LIMIT 100
#     --------------------------------------------------------------------------------
#     Neo4j Query Result: 0 records (empty)
#     Backend Result Detail: Tidak ada hasil
#     Final LLM Answer:
#     --------------------------------------------------------------------------------
#     Berdasarkan POJK No. 11/POJK.03/2022 tentang Penyelenggaraan Teknologi Informasi oleh Bank Umum, jika OJK menemukan pelanggaran berulang oleh Bank terkait pemenuhan standar ketahanan siber dan Bank tetap tidak menindaklanjuti teguran tertulis pertama, eskalasi sanksi administratif yang dapat dijatuhkan oleh OJK diatur dalam Pasal 27 ayat (2).
#
#     Awalnya, Bank yang melanggar ketentuan terkait ketahanan dan keamanan siber (sebagaimana dimaksud dalam Pasal 21 ayat (1), Pasal 22 ayat (1), ayat (4), Pasal 23, Pasal 24, Pasal 25 ayat (1), dan/atau Pasal 26 ayat (1)) akan dikenai sanksi administratif berupa **teguran tertulis**, sebagaimana diatur dalam Pasal 27 ayat (1).
#
#     Namun, dalam hal Bank telah dikenai sanksi administratif berupa teguran tertulis dan belum memenuhi ketentuan tersebut, Bank akan dikenai sanksi administratif berupa:
#     a. **larangan untuk menerbitkan produk Bank baru**;
#     b. **pembekuan kegiatan usaha tertentu**; dan/atau
#     c. **penurunan penilaian faktor tata kelola dalam penilaian tingkat kesehatan Bank**.
#
#     Ketentuan serupa mengenai eskalasi sanksi administratif ini juga ditemukan dalam Pasal 9 ayat (2), Pasal 20 ayat (2), Pasal 33 ayat (2), Pasal 42 ayat (2), Pasal 46 ayat (2), Pasal 51 ayat (2), Pasal 56 ayat (2), Pasal 63 ayat (2), dan Pasal 66 ayat (5) untuk pelanggaran terhadap ketentuan lainnya.
#     --------------------------------------------------------------------------------
#
# ====================================================================================================
#
# [99/100] HOTS_099: Apakah tindakan yang berakibat terganggunya sistem elektronik atau membuat sistem elektronik menjadi tidak bekerja semestinya dilarang menurut Pasal 33 UU ITE?
#     Status: ✅ PASS (14.1s)
#     Generated Cypher:
#     --------------------------------------------------------------------------------
#     MATCH (p)-[:MENGATUR]->(ph:PerbuatanHukum) WHERE p.source_document_id = 'UU_11_2008' AND ph.source_document_id = 'UU_11_2008' AND p.label CONTAINS 'Pasal 33' RETURN p.label AS pasal_ayat, ph.label AS perbuatan_hukum, ph.content AS detail_perbuatan, p.source_document_id AS regulasi LIMIT 100
#     --------------------------------------------------------------------------------
#     Neo4j Query Result: 1 records returned
#     --------------------------------------------------------------------------------
#     [
#       {
#         "pasal_ayat": "Pasal 33",
#         "perbuatan_hukum": "melakukan tindakan yang berakibat terganggunya Sistem Elektronik dan/atau mengakibatkan Sistem Elektronik menjadi tidak bekerja sebagaimana mestinya",
#         "detail_perbuatan": "melakukan tindakan apa pun yang berakibat terganggunya Sistem Elektronik dan/atau mengakibatkan Sistem Elektronik menjadi tidak bekerja sebagaimana mestinya",
#         "regulasi": "UU_11_2008"
#       }
#     ]
#     --------------------------------------------------------------------------------
#     Backend Result Detail: 1 hasil ditemukan
#     Final LLM Answer:
#     --------------------------------------------------------------------------------
#     Ya, tindakan yang berakibat terganggunya Sistem Elektronik atau membuat Sistem Elektronik menjadi tidak bekerja sebagaimana mestinya dilarang menurut Pasal 33 UU ITE.
#
#     Menurut **UU No. 11 Tahun 2008 tentang Informasi dan Transaksi Elektronik (UU ITE)**:
#     Pasal 33 mengatur perbuatan hukum berupa "melakukan tindakan yang berakibat terganggunya Sistem Elektronik dan/atau mengakibatkan Sistem Elektronik menjadi tidak bekerja sebagaimana mestinya". Lebih lanjut, Pasal 33 ini merujuk pada "melakukan tindakan apa pun yang berakibat terganggunya Sistem Elektronik dan/atau mengakibatkan Sistem Elektronik menjadi tidak bekerja sebagaimana mestinya".
#
#     Tindakan yang dimaksud dalam Pasal 33 ini juga dikategorikan sebagai tindak pidana sebagaimana dimaksud dalam Pasal 49.
#     --------------------------------------------------------------------------------
#
# ====================================================================================================
#
# [100/100] HOTS_100: Apakah Rencana Penyelenggaraan TI bank umum wajib disusun selaras dengan rencana strategis bank menurut Pasal 3 ayat (1) POJK 11/2022?
#     Status: ✅ PASS (19.8s)
#     Generated Cypher:
#     --------------------------------------------------------------------------------
#     MATCH (a:Ayat)
#     WHERE a.source_document_id = 'POJK_11_2022' AND toLower(a.label) = 'pasal 3 ayat (1)'
#     RETURN a.label AS ayat, a.content AS isi, a.source_document_id AS regulasi
#     LIMIT 1
#     --------------------------------------------------------------------------------
#     Neo4j Query Result: 1 records returned
#     --------------------------------------------------------------------------------
#     [
#       {
#         "ayat": "Pasal 3 ayat (1)",
#         "isi": "Dalam menerapkan tata kelola TI, Bank wajib\nmelakukan pemetaan, perencanaan, dan/atau\npenetapan atas aspek paling sedikit:\na. proses bisnis;\nb. struktur organisasi;\nc. kebijakan, standar, dan prosedur;\nd. kebutuhan dan alur informasi pendukung proses\nbisnis;\ne. sumber daya manusia pendukung;\nf. budaya TI; dan\ng. infrastruktur dan aplikasi.",
#         "regulasi": "POJK_11_2022"
#       }
#     ]
#     --------------------------------------------------------------------------------
#     Backend Result Detail: 1 hasil ditemukan
#     Final LLM Answer:
#     --------------------------------------------------------------------------------
#     Menurut POJK No. 11/POJK.03/2022 tentang Penyelenggaraan Teknologi Informasi oleh Bank Umum:
#
#     Pasal 3 ayat (1) mengatur bahwa dalam menerapkan tata kelola TI, Bank wajib melakukan pemetaan, perencanaan, dan/atau penetapan atas aspek paling sedikit:
#     a. proses bisnis;
#     b. struktur organisasi;
#     c. kebijakan, standar, dan prosedur;
#     d. kebutuhan dan alur informasi pendukung proses bisnis;
#     e. sumber daya manusia pendukung;
#     f. budaya TI; dan
#     g. infrastruktur dan aplikasi.
#
#     Mengenai kewajiban penyusunan rencana penyelenggaraan TI bank umum agar selaras dengan rencana strategis bank, informasi tersebut diatur dalam Pasal 12 ayat (2) POJK No. 11/POJK.03/2022. Pasal tersebut menyatakan bahwa **rencana strategis TI sebagaimana dimaksud pada ayat (1) disusun untuk penyelenggaraan TI dalam jangka panjang sesuai periode rencana korporasi Bank.**
#     --------------------------------------------------------------------------------
#
# ====================================================================================================
#
#
# === Done: 100 test cases evaluated ===

# %% [markdown]
# ## Step 5: Summary

# %%
# === Overall Summary ===
total = len(results_df)
passed = len(results_df[results_df['STATUS'] == 'PASS'])
failed = len(results_df[results_df['STATUS'] == 'FAIL'])
errors = len(results_df[results_df['STATUS'] == 'ERROR'])
partial = len(results_df[results_df['STATUS'] == 'PARTIAL'])
avg_time = results_df['TIME_S'].mean()

print(f'╔══════════════════════════════════════════╗')
print(f'║  Q2C E2E Evaluation Report               ║')
print(f'╠══════════════════════════════════════════╣')
print(f'║  Experiment: {EXPERIMENT_ID:<27s} ║')
print(f'║  Documents:  {", ".join(DOCUMENT_IDS):<27s} ║')
print(f'║  Backend:    {BACKEND_URL:<27s} ║')
print(f'╠══════════════════════════════════════════╣')
print(f'║  Total:   {total:>3d}                              ║')
print(f'║  Pass:    {passed:>3d}  ({passed/total:.1%})                     ║')
print(f'║  Fail:    {failed:>3d}  ({failed/total:.1%})                     ║')
print(f'║  Error:   {errors:>3d}                              ║')
print(f'║  Partial: {partial:>3d}                              ║')
print(f'║  Avg Time: {avg_time:.1f}s                          ║')
print(f'╚══════════════════════════════════════════╝')
# Out:
# ╔══════════════════════════════════════════╗
# ║  Q2C E2E Evaluation Report               ║
# ╠══════════════════════════════════════════╣
# ║  Experiment: Q2C_012                     ║
# ║  Documents:  POJK_11_2022, UU_11_2008, UU_19_2016 ║
# ║  Backend:    http://localhost:8000       ║
# ╠══════════════════════════════════════════╣
# ║  Total:   100                              ║
# ║  Pass:     77  (77.0%)                     ║
# ║  Fail:     18  (18.0%)                     ║
# ║  Error:     5                              ║
# ║  Partial:   0                              ║
# ║  Avg Time: 28.0s                          ║
# ╚══════════════════════════════════════════╝

# %%
# === Failed/Error Test Cases ===
failed_df = results_df[results_df['STATUS'] != 'PASS']

if len(failed_df) == 0:
    print('🎉 All test cases passed!')
else:
    print(f'\n❌ Failed/Error test cases ({len(failed_df)}):\n')
    for _, row in failed_df.iterrows():
        print(f"  {row['TEST_ID']}: {row['QUESTION'][:60]}")
        print(f"    Status: {row['STATUS']}")
        if row['GENERATED_CYPHER']:
            print(f"    Cypher: {row['GENERATED_CYPHER'][:100]}...")
        print()
# Out:
# ❌ Failed/Error test cases (23):
#
#   HOTS_003: Apakah sanksi administratif bagi bank umum yang melanggar ke
#     Status: FAIL
#     Cypher: MATCH (target)
# WHERE (target:Pasal OR target:Ayat)
#   AND target.source_document_id = 'POJK_11_2022'
# ...
#
#   HOTS_011: Bank D ingin menyediakan jasa infrastruktur komputasi awan (
#     Status: FAIL
#     Cypher: MATCH (n) WHERE n.source_document_id = 'POJK_11_2022' AND (n:Pasal OR n:Ayat) AND toLower(n.content)...
#
#   HOTS_023: Seorang influencer menyebarkan ulasan bohong di media sosial
#     Status: FAIL
#     Cypher: MATCH (a:Ayat)-[:MENGATUR]->(ph:PerbuatanHukum) WHERE a.source_document_id = 'UU_19_2016' AND toLowe...
#
#   HOTS_026: Bank B telah beroperasi secara digital penuh tetapi belum pe
#     Status: FAIL
#     Cypher: MATCH (n:Pasal|n:Ayat)
# WHERE n.source_document_id = 'POJK_11_2022'
#   AND (
#     (toLower(n.content) C...
#
#   HOTS_029: Bank Z berencana melakukan audit intern atas penyelenggaraan
#     Status: FAIL
#     Cypher: MATCH (a:Ayat)
# WHERE a.source_document_id = 'POJK_11_2022'
#   AND (toLower(a.content) CONTAINS 'audit...
#
#   HOTS_035: Berapakah ancaman pidana penjara dan denda maksimal bagi ses
#     Status: FAIL
#     Cypher: MATCH (a_sanksi:Ayat)-[:MERUJUK]->(a_larangan:Ayat), (a_sanksi)-[:MENETAPKAN_SANKSI]->(s:Sanksi)
# WHE...
#
#   HOTS_046: Seseorang mendistribusikan konten asusila pribadi milik mant
#     Status: FAIL
#     Cypher: MATCH (a_sanksi)-[:MERUJUK]->(a_larangan), (a_sanksi)-[:MENETAPKAN_SANKSI]->(sk:Sanksi) WHERE a_sank...
#
#   HOTS_048: Setelah resmi mendapatkan izin menempatkan DRC di luar neger
#     Status: FAIL
#     Cypher: MATCH (n) WHERE n.source_document_id = 'POJK_11_2022' AND (n:Pasal OR n:Ayat) AND (toLower(n.content...
#
#   HOTS_055: Sebuah perusahaan menyadap komunikasi email internal karyawa
#     Status: ERROR
#
#   HOTS_056: Apakah transaksi elektronik yang dituangkan ke dalam kontrak
#     Status: ERROR
#
#   HOTS_057: Apa perbedaan mendasar mengenai syarat penuntutan pidana pen
#     Status: ERROR
#
#   HOTS_058: Apakah bank umum wajib memiliki pedoman tertulis terkait fun
#     Status: ERROR
#
#   HOTS_059: Apakah sanksi pidana bagi seseorang yang dengan sengaja meng
#     Status: ERROR
#
#   HOTS_074: Apakah tindakan pengancaman secara pribadi di media sosial d
#     Status: FAIL
#     Cypher: MATCH (p29:Pasal) WHERE toLower(p29.label) = 'pasal 29' AND p29.source_document_id = 'UU_11_2008'
# OP...
#
#   HOTS_077: Siapakah yang dimaksud dengan Penanda Tangan dalam transaksi
#     Status: FAIL
#     Cypher: MATCH (p)-[:MENDEFINISIKAN]->(k:KonsepHukum) WHERE p.source_document_id = 'UU_11_2008' AND toLower(p...
#
#   HOTS_079: Apakah sanksi pidana bagi seseorang yang memproduksi, menjua
#     Status: FAIL
#     Cypher: MATCH (a:Ayat)-[:MERUJUK]->(target), (a)-[:MENETAPKAN_SANKSI]->(sk:Sanksi) WHERE a.source_document_i...
#
#   HOTS_083: Apakah perbuatan melakukan penyadapan atau intersepsi atas t
#     Status: FAIL
#     Cypher: MATCH (prohibition_ayat:Ayat)-[:MENGATUR]->(ph:PerbuatanHukum)
# WHERE prohibition_ayat.source_documen...
#
#   HOTS_084: Bank H melakukan pengujian keamanan siber (penetration test)
#     Status: FAIL
#     Cypher: MATCH (n:Ayat OR n:Pasal) WHERE n.source_document_id = 'POJK_11_2022' AND ((toLower(n.content) CONTA...
#
#   HOTS_087: Bank E mengalami kegagalan sistem keamanan di mana data kata
#     Status: FAIL
#     Cypher: MATCH (n:Pasal|Ayat) WHERE n.source_document_id = 'POJK_11_2022' AND (toLower(n.content) CONTAINS 'k...
#
#   HOTS_088: Sebuah bank umum mengalami kebocoran data nasabah akibat kel
#     Status: FAIL
#     Cypher: MATCH (n:Pasal OR n:Ayat)
# WHERE n.source_document_id IN ['POJK_11_2022', 'UU_11_2008', 'UU_19_2016']...
#
#   HOTS_089: Sebuah aplikasi dompet digital mengalami kelumpuhan transaks
#     Status: FAIL
#     Cypher: MATCH (a:Ayat)-[:BERLAKU_UNTUK]->(e:EntitasHukum) WHERE a.source_document_id = 'UU_11_2008' AND e.so...
#
#   HOTS_092: Apakah definisi dan fungsi utama dari tanda tangan elektroni
#     Status: FAIL
#     Cypher: MATCH (a:Ayat)-[:MENDEFINISIKAN]->(k:KonsepHukum) WHERE a.source_document_id = 'UU_11_2008' AND toLo...
#
#   HOTS_098: Jika OJK menemukan pelanggaran berulang oleh Bank terkait pe
#     Status: FAIL
#     Cypher: MATCH (a:Ayat)-[:MENETAPKAN_SANKSI]->(s:Sanksi)
# WHERE a.source_document_id = 'POJK_11_2022' AND s.so...

# %% [markdown]
# ## Step 6: Save Results

# %%
# === Save to CSV ===
output_dir = 'data/evaluation'
os.makedirs(output_dir, exist_ok=True)

output_csv = f'{output_dir}/e2e_eval_{EXPERIMENT_ID}.csv'
results_df.to_csv(output_csv, index=False, encoding='utf-8')
print(f'✅ Results saved to: {output_csv}')
# Out:
# ✅ Results saved to: data/evaluation/e2e_eval_Q2C_012.csv

# %%
# === (Optional) Write to Google Sheets ===
if WRITE_TO_GSHEETS:
    from modules.google_sheets_utils import GoogleUtil, GoogleSheetsWriter
    import gspread

    gu = GoogleUtil(
        private_key=os.getenv('GOOGLE_SHEETS_PRIVATE_KEY', ''),
        client_email=os.getenv('GOOGLE_SHEETS_CLIENT_EMAIL', '')
    )
    spreadsheet_id = os.getenv('GOOGLE_SPREADSHEET_ID', '')

    # Auto-create worksheet if it does not exist
    try:
        info = gu._get_google_info(gu.private_key, gu.client_email)
        client = gu._get_client(info, gu.GOOGLE_SHEETS_SCOPES)
        sh = client.open_by_key(spreadsheet_id)
        try:
            ws = sh.worksheet(EXPERIMENT_SHEET_NAME)
            print(f'ℹ️  Sheet "{EXPERIMENT_SHEET_NAME}" already exists.')
        except gspread.exceptions.WorksheetNotFound:
            ws = sh.add_worksheet(title=EXPERIMENT_SHEET_NAME, rows=1000, cols=20)
            # Write header row
            headers = list(results_df.columns)
            ws.update([headers], "A1")
            print(f'✅ Created new sheet: "{EXPERIMENT_SHEET_NAME}"')
    except Exception as e:
        print(f'⚠️  Could not auto-create sheet: {e}')

    writer = GoogleSheetsWriter(
        google_util=gu,
        sheet_id=spreadsheet_id,
        worksheet_name=EXPERIMENT_SHEET_NAME,
        batch_size=5,
    )

    result = writer.write_dataframe(results_df)
    print(f'✅ Written to Google Sheets: {EXPERIMENT_SHEET_NAME}')
    print(f'   Success: {result.successful_rows}, Failed: {result.failed_rows}')
else:
    print('ℹ️  WRITE_TO_GSHEETS = False, skipping Google Sheets upload.')
    print(f'   Set WRITE_TO_GSHEETS = True to write results to sheet "{EXPERIMENT_SHEET_NAME}"')
# Out:
# ℹ️  WRITE_TO_GSHEETS = False, skipping Google Sheets upload.
#    Set WRITE_TO_GSHEETS = True to write results to sheet "EXP_E2E_HOTS_Q2C_TEST_DATA_V3_POJK_11_2022_UU_11_2008_UU_19_2016"

# %%
# === Preview Results ===
print(f"\n{'='*80}")
print(f"RESULTS PREVIEW — First 5 rows")
print(f"{'='*80}")

for _, row in results_df.head(5).iterrows():
    print(f"\n--- {row['TEST_ID']} [{row['STATUS']}] ---")
    print(f"Q: {row['QUESTION']}")
    print(f"Cypher: {row['GENERATED_CYPHER'][:150]}..." if len(str(row['GENERATED_CYPHER'])) > 150 else f"Cypher: {row['GENERATED_CYPHER']}")
    print(f"Neo4j Result: {str(row['CYPHER_QUERY_RESULT'])[:200]}..." if len(str(row['CYPHER_QUERY_RESULT'])) > 200 else f"Neo4j Result: {row['CYPHER_QUERY_RESULT']}")
    print(f"Answer: {str(row['ANSWER'])[:200]}..." if len(str(row['ANSWER'])) > 200 else f"Answer: {row['ANSWER']}")
# Out:
# ================================================================================
# RESULTS PREVIEW — First 5 rows
# ================================================================================
#
# --- HOTS_001 [PASS] ---
# Q: Apakah dilarang menyebarkan informasi elektronik yang bermuatan penghinaan dan/atau pencemaran nama baik, dan berapa sanksi pidana maksimalnya berdasarkan UU ITE?
# Cypher: MATCH (prohibition_ayat)-[:MENGATUR]->(ph:PerbuatanHukum) WHERE prohibition_ayat.source_document_id = 'UU_11_2008' AND prohibition_ayat.label CONTAINS...
# Neo4j Result: [{"pasal_larangan": "Pasal 27 ayat (3)", "perbuatan_dilarang": "mendistribusikan dan/atau mentransmisikan dan/atau membuat dapat diaksesnya Informasi Elektronik dan/atau Dokumen Elektronik yang memili...
# Answer: Berdasarkan UU No. 11 Tahun 2008 tentang Informasi dan Transaksi Elektronik (UU ITE), dilarang untuk menyebarkan informasi elektronik yang bermuatan penghinaan dan/atau pencemaran nama baik.
#
# Larangan...
#
# --- HOTS_002 [PASS] ---
# Q: Siapakah saja yang paling sedikit harus menjadi anggota Komite Pengarah TI bank umum menurut Pasal 7 ayat (3) POJK 11/2022?
# Cypher: MATCH (a:Ayat)-[:BERLAKU_UNTUK]->(e:EntitasHukum) WHERE a.source_document_id = 'POJK_11_2022' AND a.label CONTAINS 'Pasal 7 ayat (3)' RETURN a.label A...
# Neo4j Result: [{"pasal_ayat": "Pasal 7 ayat (3)", "isi_ayat": "Komite pengarah TI sebagaimana dimaksud pada\nayat (1) paling sedikit beranggotakan:\na. direktur yang membawahkan satuan kerja\npenyelenggara TI;\nb. ...
# Answer: Menurut POJK No. 11/POJK.03/2022, Pasal 7 ayat (3) mengatur bahwa Komite pengarah TI paling sedikit beranggotakan:
# a. direktur yang membawahkan satuan kerja penyelenggara TI;
# b. direktur yang membawah...
#
# --- HOTS_003 [FAIL] ---
# Q: Apakah sanksi administratif bagi bank umum yang melanggar ketentuan tata kelola TI dan tidak menindaklanjuti teguran tertulis pertama menurut Pasal 9 POJK 11/2022?
# Cypher: MATCH (target)
# WHERE (target:Pasal OR target:Ayat)
#   AND target.source_document_id = 'POJK_11_2022'
#   AND target.label CONTAINS 'Pasal 9'
# MATCH (a:Aya...
# Neo4j Result:
# Answer: Menurut POJK No. 11/POJK.03/2022 tentang Penyelenggaraan Teknologi Informasi oleh Bank Umum, Pasal 9 ayat (2) mengatur bahwa dalam hal Bank telah dikenai sanksi administratif berupa teguran tertulis s...
#
# --- HOTS_004 [PASS] ---
# Q: Dalam Pasal 34 ayat (1) UU Nomor 11 Tahun 2008, terdapat larangan memproduksi atau mendistribusikan perangkat keras atau lunak untuk memfasilitasi perbuatan dalam Pasal 27 sampai Pasal 33. Apa bunyi dari ketentuan Pasal 34 ayat (1) tersebut?
# Cypher: MATCH (a:Ayat) WHERE toLower(a.label) = 'pasal 34 ayat (1)' AND a.source_document_id = 'UU_11_2008' RETURN a.label AS ayat, a.content AS isi, a.source...
# Neo4j Result: [{"ayat": "Pasal 34 ayat (1)", "isi": "Setiap Orang dengan sengaja dan tanpa hak atau melawan hukum memproduksi, menjual, mengadakan untuk digunakan, mengimpor, mendistribusikan, menyediakan, atau mem...
# Answer: Menurut UU No. 11 Tahun 2008 tentang Informasi dan Transaksi Elektronik (UU ITE), bunyi dari Pasal 34 ayat (1) adalah sebagai berikut:
#
# **Pasal 34 ayat (1)**
# "Setiap Orang dengan sengaja dan tanpa hak...
#
# --- HOTS_005 [PASS] ---
# Q: Apakah individu atau masyarakat diperbolehkan mengelola nama domain sendiri menurut Pasal 24 ayat (1) UU Nomor 11 Tahun 2008?
# Cypher: MATCH (a:Ayat) WHERE a.source_document_id = 'UU_11_2008' AND a.label CONTAINS 'Pasal 24 ayat (1)' OPTIONAL MATCH (a)-[:BERLAKU_UNTUK]->(e:EntitasHukum...
# Neo4j Result: [{"pasal_ayat": "Pasal 24 ayat (1)", "isi_ketentuan": "Pengelola Nama Domain adalah Pemerintah dan/atau masyarakat.", "berlaku_untuk": "masyarakat", "regulasi": "UU_11_2008"}, {"pasal_ayat": "Pasal 24...
# Answer: Menurut UU No. 11 Tahun 2008 tentang Informasi dan Transaksi Elektronik, Pasal 24 ayat (1) menyatakan bahwa Pengelola Nama Domain adalah Pemerintah dan/atau masyarakat. Ini berarti individu atau masya...

# %%
print('\n✅ Evaluation complete.')
# Out:
# ✅ Evaluation complete.
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
